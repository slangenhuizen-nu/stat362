# %% [raw]
# ---
# title: "Quiz 5: Regularized Gradient Descent for Linear Regression"
# format:
#   html:
#     toc: true
#     toc-title: Contents
#     number-sections: true
#     toc-depth: 4
#     code-fold: show
#     self-contained: true
# jupyter: python3
# ---

# %% [markdown]
# ##  Learning Objectives
#
# By the end of this comprehensive lab, you will master the following key concepts and skills:
#
# ### Theoretical Understanding
# * **Grasp the overfitting problem**: Understand how complex models can memorize training data but fail to generalize
# * **Learn regularization fundamentals**: Discover how L1 and L2 penalties constrain model complexity
# * **Mathematical foundations**: Derive and understand the modified cost functions and gradient formulas for regularized regression
#
# ### Implementation Mastery
# * **Extend cost functions**: Add L1 (Lasso) and L2 (Ridge) regularization terms to prevent overfitting
# * **Vectorized gradient descent**: Implement efficient, matrix-based gradient descent algorithms for both regularization types
# * **Handle non-differentiability**: Navigate the challenges of L1 regularization's non-smooth optimization landscape
# * **Professional coding practices**: Write clean, documented, and efficient machine learning code
#
# ### Practical Application
# * **Real overfitting scenario**: Work with a deliberately overfitted polynomial regression model
# * **Hyperparameter tuning**: Explore how regularization strength (λ) affects model behavior
# * **Scikit-learn integration**: Leverage industry-standard Lasso and Ridge implementations
# * **Performance evaluation**: Use RMSE and learning curves to assess model quality
#
# ### Comparative Analysis
# * **Method comparison**: Systematically compare custom implementations vs. scikit-learn
# * **L1 vs L2 analysis**: Understand when to use Lasso (feature selection) vs Ridge (parameter shrinkage)
# * **Bias-variance tradeoff**: Observe how regularization balances underfitting and overfitting
# * **Convergence behavior**: Analyze training vs. test performance across different approaches
#
# ### Key Insights You'll Gain
# * Why regularization is essential for small datasets and high-dimensional features
# * How L1 regularization promotes sparsity (automatic feature selection)
# * Why L2 regularization provides smoother, more stable solutions
# * When to choose custom implementations vs. pre-built libraries in real-world projects

# %% [markdown]
# ## Essential Libraries and Dependencies
#
# We'll import the core libraries needed for this comprehensive regularization lab:
#
# - **NumPy & Matplotlib**: Numerical computing and data visualization
# - **Pandas**: Data manipulation and analysis framework
# - **Scikit-learn**: Professional ML implementations (Lasso, Ridge, StandardScaler)
# - **Math & Copy**: Utility functions for mathematical operations and object copying

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import copy, math
from sklearn.linear_model import Lasso, Ridge
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Synthetic Dataset Creation: Setting Up for Overfitting
#
# **Educational Purpose**: We'll deliberately create a scenario prone to overfitting:
#
# - **Small sample size** (only ~10% for training)
# - **High-dimensional features** (polynomial terms up to x^15)
# - **Noisy target function** (sine wave + random noise)
#
# This setup perfectly demonstrates why regularization is essential in machine learning!

# %%
#Define input array with angles from 60deg to 300deg converted to radians
x = np.array([i*np.pi/60 for i in range(120)])
# x = np.array([i*np.pi/180 for i in range(360)])

np.random.seed(10)  #Setting seed for reproducibility
y = np.sin(x) + np.random.normal(0,0.15,len(x))
data = pd.DataFrame(np.column_stack([x,y]),columns=['x','y'])
plt.plot(data['x'],data['y'],'.')
plt.show()

# %%
for i in range(2,16):  #power of 1 is already there
    colname = 'x_%d'%i      #new var will be x_power
    data[colname] = data['x']**i
print(data.head())
# Out:
#          x         y       x_2       x_3       x_4           x_5  \
# 0  0.00000  0.199738  0.000000  0.000000  0.000000  0.000000e+00
# 1  0.05236  0.159628  0.002742  0.000144  0.000008  3.935438e-07
# 2  0.10472 -0.127282  0.010966  0.001148  0.000120  1.259340e-05
# 3  0.15708  0.155177  0.024674  0.003876  0.000609  9.563115e-05
# 4  0.20944  0.301112  0.043865  0.009187  0.001924  4.029889e-04
#
#             x_6           x_7           x_8           x_9          x_10  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1  2.060591e-08  1.078923e-09  5.649226e-11  2.957928e-12  1.548767e-13
# 2  1.318778e-06  1.381021e-07  1.446202e-08  1.514459e-09  1.585938e-10
# 3  1.502171e-05  2.359604e-06  3.706457e-07  5.822090e-08  9.145317e-09
# 4  8.440179e-05  1.767707e-05  3.702277e-06  7.754031e-07  1.624000e-07
#
#            x_11          x_12          x_13          x_14          x_15
# 0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1  8.109328e-15  4.246034e-16  2.223218e-17  1.164074e-18  6.095079e-20
# 2  1.660790e-11  1.739176e-12  1.821260e-13  1.907219e-14  1.997235e-15
# 3  1.436543e-09  2.256517e-10  3.544528e-11  5.567731e-12  8.745772e-13
# 4  3.401299e-08  7.123663e-09  1.491976e-09  3.124788e-10  6.544541e-11

# %%
# split into train and test 
np.random.seed(123)
# split the data into train and test, less data is prone to overfitting, so we will only use  10% data for training
mask = np.random.rand(len(data)) < 0.1
train = data[mask]
test = data[~mask]
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))
# Out:
# Number of observations in the training data: 7
# Number of observations in the test data: 113

# %%
# split feature and target
X_train = train.drop('y', axis=1).values
y_train = train['y'].values
X_test = test.drop('y', axis=1).values
y_test = test['y'].values

# %%
plt.plot(X_train[:,0], y_train, 'b.')

# %% [markdown]
# ## Critical Observation: The Perfect Storm for Overfitting
#
# This is a textbook case where regularization becomes absolutely essential!
#
# Notice the dangerous combination we've created:
#
# - **Extremely small training set**: Only ~7-12 training instances
#    - No regularization means unlimited parameter growth
#
#
# - **High feature dimensionality**: 15 polynomial features
#    - Each polynomial term can memorize individual training points
#
# - **Complex underlying pattern**: Sine wave with noise
#
#
# **Why this leads to overfitting:**
#
# - The model has more parameters (15) than training examples (~7-12)

# %%
# do standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Baseline Implementation: Vanilla Gradient Descent
#
# ### Prerequisites: Building on Previous Knowledge
#
# Before we add regularization, let's establish our baseline with standard gradient descent.
#
# **Key Requirement**: Modified to track both training AND test performance to demonstrate overfitting.
#
# **Your Task**: Implement the core gradient descent functions from your previous lab:
#
# - `compute_cost_matrix()`: Calculate MSE cost using vectorization
# - `gradient_descent_matrix()`: Main optimization loop
# - `compute_gradient_matrix()`: Compute gradients efficiently

# %%
def compute_cost_matrix(X, y, w):
    """
    Computes the Mean Squared Error cost for linear regression using vectorization
    
    Mathematical Formula: J(w) = (1/2m) * ||Xw - y||²
    
    Args:
      X (ndarray (m,n+1)): Feature matrix, m training examples with n+1 features (including bias)
      y (ndarray (m,)): Target values for training examples
      w (ndarray (n+1,)): Model parameters (weights + bias)
      
    Returns:
      cost (scalar): Mean squared error cost
      

    Implementation Hint:    return cost

      Use vectorized operations: (X @ w - y).T @ (X @ w - y) / (2*m)    

    """    # Formula: J = (1/2m) * (predictions - targets)^2
    # TODO: Implement vectorized MSE cost calculation

    m = X.shape[0]
    predicted_y = X @ w
    errors = predicted_y - y
    squared_errors = np.dot(errors.T, errors)
    cost = squared_errors / (2*m)

    return cost

# %%
def compute_gradient_matrix(X, y, w):
    """
    Computes the gradient of MSE cost w.r.t. parameters using vectorization
    
    Mathematical Formula: ∇J(w) = (1/m) * X.T @ (Xw - y)
    
    Args:
      X (ndarray (m,n+1)): Feature matrix with bias column
      y (ndarray (m,)): Target values 
      w (ndarray (n+1,)): Current model parameters
      
    Returns:
      dj_dw (ndarray (n+1,)): Gradient vector for all parameters
      
    Implementation Hint:

      Vectorized form avoids loops: X.T @ (predictions - targets) / m    return dj_dw

    """    

    # TODO: Implement vectorized gradient calculation    # Formula: dJ/dw = (1/m) * X.T * (X*w - y)

    m = X.shape[0] 
    predicted_y = X @ w
    errors = predicted_y - y
    dj_dw = (X.T @ errors) / m
    
    return dj_dw

# %% [markdown]
# ## Enhanced Gradient Descent: Tracking Overfitting in Real-Time
#
# - Return both cost histories for visualization
#
# **Critical Modification**: We need to monitor BOTH training and test performance simultaneously to observe overfitting as it happens.
#
# - Print progress every 1000 iterations for monitoring
# - Calculate test cost at each iteration (without updating weights on test data)
#
# **Key Requirements:**
#
# - Track training cost at each iteration

# %%
def gradient_descent_matrix(X, y, X_test, y_test, w_in, alpha, num_iters): 
    """
    Performs batch gradient descent to learn w. Updates w by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (?,n+1))   : Training set, ? examples with n features
      y (ndarray (?,))    : target values in test set
      X_test (ndarray (?,n+1))   : Test set, ? examples with n features
      y_test (ndarray (?,))    : target values in test set
      w_in (ndarray (n+1,)) : initial model parameters  
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent
      
    Returns:
      w (ndarray (n+1,)) : Updated values of parameters
      J_history           : Cost of the model on the training set after each iteration
      test_J_history      : Cost of the model on test set after each iteration
      """
    
    # implement the batch gradient descent algorithm using the compute_gradient and compute_cost functions

    J_history = []
    test_J_history = []
    w = copy.deepcopy(w_in)

    for i in range(num_iters):
        gradient = compute_gradient_matrix(X, y, w)
        w = w - (alpha*gradient)
        cost = compute_cost_matrix(X, y, w)
        J_history.append(cost)
        test_cost = compute_cost_matrix(X_test, y_test, w)
        test_J_history.append(test_cost)
        if i % 100 == 0:
            print(f"For iteration {i+1}/{num_iters}, the training cost is {cost}.")
            print(f"For iteration {i+1}/{num_iters}, the test cost is {test_cost}.")

    
    return w, J_history, test_J_history

# %% [markdown]
# ## Testing Your Implementation: Demonstrating Overfitting
#
# **Expected Outcome**: You should observe the training cost decreasing while test cost increases - classic overfitting!
#
# **Experiment Parameters:**
#
# - Learning rate: `alpha = 0.1` (aggressive for faster convergence)
# - Data: Use standardized features (`X_train_scaled`, `X_test_scaled`)
# - Iterations: `num_iters = 50000` (ensure full convergence)

# %%
# Do the gradient descent with the scaled data
# add a column of ones to the X_train

m = X_train_scaled.shape[0]
ones_column = np.ones((m, 1))
X_train_scaled_ones = np.c_[ones_column, X_train_scaled]

test_m = X_test_scaled.shape[0]
test_ones_column = np.ones((test_m, 1))
X_test_scaled_ones = np.c_[test_ones_column, X_test_scaled]

n = X_train_scaled_ones.shape[1] 
w_initial = np.zeros(n)

w_vanilla_gd, J_history, test_J_history = gradient_descent_matrix(X_train_scaled_ones, y_train, X_test_scaled_ones, y_test, w_initial, 0.1, 50000)
# Out:
# For iteration 1/50000, the training cost is 0.1866960528996568.
# For iteration 1/50000, the test cost is 0.2092898934425311.
# For iteration 101/50000, the training cost is 0.010342119263466037.
# For iteration 101/50000, the test cost is 0.08919214685427224.
# For iteration 201/50000, the training cost is 0.010149628192513305.
# For iteration 201/50000, the test cost is 0.08803048126840383.
# For iteration 301/50000, the training cost is 0.009973061046526685.
# For iteration 301/50000, the test cost is 0.08679954747551315.
# For iteration 401/50000, the training cost is 0.009807139373445307.
# For iteration 401/50000, the test cost is 0.08553759343084641.
# For iteration 501/50000, the training cost is 0.009648656388554977.
# For iteration 501/50000, the test cost is 0.08425382892922649.
# For iteration 601/50000, the training cost is 0.00949565338926155.
# For iteration 601/50000, the test cost is 0.08295769676135606.
# For iteration 701/50000, the training cost is 0.0093469277855081.
# For iteration 701/50000, the test cost is 0.08165775846152351.
# For iteration 801/50000, the training cost is 0.009201735160985923.
# For iteration 801/50000, the test cost is 0.08036127009803452.
# For iteration 901/50000, the training cost is 0.00905960883840146.
# For iteration 901/50000, the test cost is 0.07907411806182375.
# For iteration 1001/50000, the training cost is 0.008920250604629266.
# For iteration 1001/50000, the test cost is 0.07780092541033456.
# For iteration 1101/50000, the training cost is 0.008783464529975334.
# For iteration 1101/50000, the test cost is 0.07654522564148404.
# For iteration 1201/50000, the training cost is 0.008649116885071848.
# For iteration 1201/50000, the test cost is 0.07530965022843518.
# For iteration 1301/50000, the training cost is 0.00851711186242712.
# For iteration 1301/50000, the test cost is 0.07409610405859207.
# For iteration 1401/50000, the training cost is 0.00838737686926104.
# For iteration 1401/50000, the test cost is 0.07290591814332369.
# For iteration 1501/50000, the training cost is 0.008259853616729576.
# For iteration 1501/50000, the test cost is 0.07173997695657118.
# For iteration 1601/50000, the training cost is 0.008134492719481422.
# For iteration 1601/50000, the test cost is 0.07059882167082163.
# For iteration 1701/50000, the training cost is 0.008011250421121814.
# For iteration 1701/50000, the test cost is 0.06948273222365974.
# For iteration 1801/50000, the training cost is 0.00789008660718203.
# For iteration 1801/50000, the test cost is 0.06839179162425209.
# For iteration 1901/50000, the training cost is 0.0077709635978627425.
# For iteration 1901/50000, the test cost is 0.0673259357952995.
# For iteration 2001/50000, the training cost is 0.007653845413069771.
# For iteration 2001/50000, the test cost is 0.06628499187322846.
# For iteration 2101/50000, the training cost is 0.007538697323532589.
# For iteration 2101/50000, the test cost is 0.0652687074342457.
# For iteration 2201/50000, the training cost is 0.007425485575236701.
# For iteration 2201/50000, the test cost is 0.0642767726651623.
# For iteration 2301/50000, the training cost is 0.007314177218876764.
# For iteration 2301/50000, the test cost is 0.06330883709565065.
# For iteration 2401/50000, the training cost is 0.007204740002971157.
# For iteration 2401/50000, the test cost is 0.06236452216668104.
# For iteration 2501/50000, the training cost is 0.007097142305590478.
# For iteration 2501/50000, the test cost is 0.061443430628803836.
# For iteration 2601/50000, the training cost is 0.006991353089529798.
# For iteration 2601/50000, the test cost is 0.06054515353804866.
# For iteration 2701/50000, the training cost is 0.006887341871737046.
# For iteration 2701/50000, the test cost is 0.05966927543856866.
# For iteration 2801/50000, the training cost is 0.006785078701432555.
# For iteration 2801/50000, the test cost is 0.058815378181561316.
# For iteration 2901/50000, the training cost is 0.006684534143548311.
# For iteration 2901/50000, the test cost is 0.057983043721894015.
# For iteration 3001/50000, the training cost is 0.006585679265444797.
# For iteration 3001/50000, the test cost is 0.05717185615074205.
# For iteration 3101/50000, the training cost is 0.006488485625667222.
# For iteration 3101/50000, the test cost is 0.05638140315899943.
# For iteration 3201/50000, the training cost is 0.006392925263990809.
# For iteration 3201/50000, the test cost is 0.05561127707786008.
# For iteration 3301/50000, the training cost is 0.0062989706922996925.
# For iteration 3301/50000, the test cost is 0.0548610756063112.
# For iteration 3401/50000, the training cost is 0.006206594886022473.
# For iteration 3401/50000, the test cost is 0.05413040230758234.
# For iteration 3501/50000, the training cost is 0.006115771275956254.
# For iteration 3501/50000, the test cost is 0.05341886693573503.
# For iteration 3601/50000, the training cost is 0.006026473740376257.
# For iteration 3601/50000, the test cost is 0.05272608563790207.
# For iteration 3701/50000, the training cost is 0.005938676597367654.
# For iteration 3701/50000, the test cost is 0.05205168106594401.
# For iteration 3801/50000, the training cost is 0.005852354597340769.
# For iteration 3801/50000, the test cost is 0.05139528242250618.
# For iteration 3901/50000, the training cost is 0.005767482915705175.
# For iteration 3901/50000, the test cost is 0.050756525459912535.
# For iteration 4001/50000, the training cost is 0.005684037145686793.
# For iteration 4001/50000, the test cost is 0.050135052445456296.
# For iteration 4101/50000, the training cost is 0.005601993291278104.
# For iteration 4101/50000, the test cost is 0.04953051210303066.
# For iteration 4201/50000, the training cost is 0.005521327760314135.
# For iteration 4201/50000, the test cost is 0.04894255953835932.
# For iteration 4301/50000, the training cost is 0.005442017357669512.
# For iteration 4301/50000, the test cost is 0.048370856153109994.
# For iteration 4401/50000, the training cost is 0.005364039278572598.
# For iteration 4401/50000, the test cost is 0.04781506955171189.
# For iteration 4501/50000, the training cost is 0.005287371102033843.
# For iteration 4501/50000, the test cost is 0.04727487344362989.
# For iteration 4601/50000, the training cost is 0.005211990784385614.
# For iteration 4601/50000, the test cost is 0.046749947543060104.
# For iteration 4701/50000, the training cost is 0.005137876652931416.
# For iteration 4701/50000, the test cost is 0.04623997746744277.
# For iteration 4801/50000, the training cost is 0.005065007399702268.
# For iteration 4801/50000, the test cost is 0.045744654635769474.
# For iteration 4901/50000, the training cost is 0.004993362075318468.
# For iteration 4901/50000, the test cost is 0.045263676167363834.
# For iteration 5001/50000, the training cost is 0.004922920082954785.
# For iteration 5001/50000, the test cost is 0.044796744781596134.
# For iteration 5101/50000, the training cost is 0.004853661172407096.
# For iteration 5101/50000, the test cost is 0.044343568698839694.
# For iteration 5201/50000, the training cost is 0.004785565434259202.
# For iteration 5201/50000, the test cost is 0.04390386154286551.
# For iteration 5301/50000, the training cost is 0.004718613294147688.
# For iteration 5301/50000, the test cost is 0.04347734224479622.
# For iteration 5401/50000, the training cost is 0.004652785507123317.
# For iteration 5401/50000, the test cost is 0.04306373494868479.
# For iteration 5501/50000, the training cost is 0.004588063152107353.
# For iteration 5501/50000, the test cost is 0.04266276891874826.
# For iteration 5601/50000, the training cost is 0.004524427626441188.
# For iteration 5601/50000, the test cost is 0.04227417844826102.
# For iteration 5701/50000, the training cost is 0.004461860640527658.
# For iteration 5701/50000, the test cost is 0.0418977027700961.
# For iteration 5801/50000, the training cost is 0.004400344212562608.
# For iteration 5801/50000, the test cost is 0.0415330859688917.
# For iteration 5901/50000, the training cost is 0.004339860663355078.
# For iteration 5901/50000, the test cost is 0.041180076894816044.
# For iteration 6001/50000, the training cost is 0.004280392611234656.
# For iteration 6001/50000, the test cost is 0.04083842907889711.
# For iteration 6101/50000, the training cost is 0.004221922967044557.
# For iteration 6101/50000, the test cost is 0.040507900649884875.
# For iteration 6201/50000, the training cost is 0.0041644349292189065.
# For iteration 6201/50000, the test cost is 0.040188254252611556.
# For iteration 6301/50000, the training cost is 0.004107911978942984.
# For iteration 6301/50000, the test cost is 0.039879256967816856.
# For iteration 6401/50000, the training cost is 0.004052337875394814.
# For iteration 6401/50000, the test cost is 0.039580680233405136.
# For iteration 6501/50000, the training cost is 0.0039976966510667945.
# For iteration 6501/50000, the test cost is 0.03929229976710358.
# For iteration 6601/50000, the training cost is 0.0039439726071662665.
# For iteration 6601/50000, the test cost is 0.039013895490490696.
# For iteration 6701/50000, the training cost is 0.0038911503090932474.
# For iteration 6701/50000, the test cost is 0.03874525145436624.
# For iteration 6801/50000, the training cost is 0.003839214581994377.
# For iteration 6801/50000, the test cost is 0.038486155765435.
# For iteration 6901/50000, the training cost is 0.0037881505063916917.
# For iteration 6901/50000, the test cost is 0.03823640051427757.
# For iteration 7001/50000, the training cost is 0.0037379434138849594.
# For iteration 7001/50000, the test cost is 0.03799578170458272.
# For iteration 7101/50000, the training cost is 0.0036885788829263163.
# For iteration 7101/50000, the test cost is 0.037764099183616784.
# For iteration 7201/50000, the training cost is 0.00364004273466606.
# For iteration 7201/50000, the test cost is 0.0375411565739066.
# For iteration 7301/50000, the training cost is 0.003592321028868188.
# For iteration 7301/50000, the test cost is 0.03732676120611261.
# For iteration 7401/50000, the training cost is 0.0035454000598949755.
# For iteration 7401/50000, the test cost is 0.037120724053071014.
# For iteration 7501/50000, the training cost is 0.003499266352758847.
# For iteration 7501/50000, the test cost is 0.0369228596649825.
# For iteration 7601/50000, the training cost is 0.003453906659240811.
# For iteration 7601/50000, the test cost is 0.036732986105727804.
# For iteration 7701/50000, the training cost is 0.0034093079540741937.
# For iteration 7701/50000, the test cost is 0.036550924890289084.
# For iteration 7801/50000, the training cost is 0.003365457431192661.
# For iteration 7801/50000, the test cost is 0.036376500923257823.
# For iteration 7901/50000, the training cost is 0.003322342500041277.
# For iteration 7901/50000, the test cost is 0.036209542438410146.
# For iteration 8001/50000, the training cost is 0.003279950781949703.
# For iteration 8001/50000, the test cost is 0.03604988093933049.
# For iteration 8101/50000, the training cost is 0.0032382701065664073.
# For iteration 8101/50000, the test cost is 0.03589735114106544.
# For iteration 8201/50000, the training cost is 0.0031972885083529144.
# For iteration 8201/50000, the test cost is 0.03575179091279007.
# For iteration 8301/50000, the training cost is 0.0031569942231370715.
# For iteration 8301/50000, the test cost is 0.035613041221468564.
# For iteration 8401/50000, the training cost is 0.003117375684724167.
# For iteration 8401/50000, the test cost is 0.035480946076492575.
# For iteration 8501/50000, the training cost is 0.0030784215215653534.
# For iteration 8501/50000, the test cost is 0.035355352475280065.
# For iteration 8601/50000, the training cost is 0.0030401205534818466.
# For iteration 8601/50000, the test cost is 0.03523611034981816.
# For iteration 8701/50000, the training cost is 0.0030024617884444635.
# For iteration 8701/50000, the test cost is 0.03512307251413367.
# For iteration 8801/50000, the training cost is 0.002965434419407218.
# For iteration 8801/50000, the test cost is 0.03501609461267573.
# For iteration 8901/50000, the training cost is 0.002929027821194331.
# For iteration 8901/50000, the test cost is 0.03491503506959414.
# For iteration 9001/50000, the training cost is 0.0028932315474395217.
# For iteration 9001/50000, the test cost is 0.03481975503889896.
# For iteration 9101/50000, the training cost is 0.0028580353275768295.
# For iteration 9101/50000, the test cost is 0.03473011835548537.
# For iteration 9201/50000, the training cost is 0.002823429063882144.
# For iteration 9201/50000, the test cost is 0.03464599148700951.
# For iteration 9301/50000, the training cost is 0.002789402828564468.
# For iteration 9301/50000, the test cost is 0.03456724348660079.
# For iteration 9401/50000, the training cost is 0.002755946860906043.
# For iteration 9401/50000, the test cost is 0.03449374594639555.
# For iteration 9501/50000, the training cost is 0.002723051564450869.
# For iteration 9501/50000, the test cost is 0.034425372951879356.
# For iteration 9601/50000, the training cost is 0.0026907075042402057.
# For iteration 9601/50000, the test cost is 0.034362001037022596.
# For iteration 9701/50000, the training cost is 0.0026589054040948206.
# For iteration 9701/50000, the test cost is 0.034303509140196635.
# For iteration 9801/50000, the training cost is 0.002627636143942922.
# For iteration 9801/50000, the test cost is 0.034249778560857494.
# For iteration 9901/50000, the training cost is 0.002596890757193081.
# For iteration 9901/50000, the test cost is 0.03420069291698273.
# For iteration 10001/50000, the training cost is 0.0025666604281512078.
# For iteration 10001/50000, the test cost is 0.03415613810324994.
# For iteration 10101/50000, the training cost is 0.002536936489481264.
# For iteration 10101/50000, the test cost is 0.03411600224994299.
# For iteration 10201/50000, the training cost is 0.0025077104197084644.
# For iteration 10201/50000, the test cost is 0.03408017568257464.
# For iteration 10301/50000, the training cost is 0.0024789738407646534.
# For iteration 10301/50000, the test cost is 0.03404855088221217.
# For iteration 10401/50000, the training cost is 0.0024507185155749366.
# For iteration 10401/50000, the test cost is 0.034021022446495276.
# For iteration 10501/50000, the training cost is 0.0024229363456848563.
# For iteration 10501/50000, the test cost is 0.033997487051332605.
# For iteration 10601/50000, the training cost is 0.002395619368927664.
# For iteration 10601/50000, the test cost is 0.033977843413267386.
# For iteration 10701/50000, the training cost is 0.0023687597571306986.
# For iteration 10701/50000, the test cost is 0.03396199225249888.
# For iteration 10801/50000, the training cost is 0.0023423498138603954.
# For iteration 10801/50000, the test cost is 0.03394983625654946.
# For iteration 10901/50000, the training cost is 0.002316381972205354.
# For iteration 10901/50000, the test cost is 0.03394128004456594.
# For iteration 11001/50000, the training cost is 0.002290848792596499.
# For iteration 11001/50000, the test cost is 0.03393623013224424.
# For iteration 11101/50000, the training cost is 0.0022657429606641882.
# For iteration 11101/50000, the test cost is 0.033934594897366784.
# For iteration 11201/50000, the training cost is 0.002241057285131173.
# For iteration 11201/50000, the test cost is 0.033936284545942094.
# For iteration 11301/50000, the training cost is 0.0022167846957411004.
# For iteration 11301/50000, the test cost is 0.03394121107893613.
# For iteration 11401/50000, the training cost is 0.002192918241221844.
# For iteration 11401/50000, the test cost is 0.033949288259585673.
# For iteration 11501/50000, the training cost is 0.0021694510872832386.
# For iteration 11501/50000, the test cost is 0.03396043158128296.
# For iteration 11601/50000, the training cost is 0.002146376514648285.
# For iteration 11601/50000, the test cost is 0.03397455823602249.
# For iteration 11701/50000, the training cost is 0.0021236879171176596.
# For iteration 11701/50000, the test cost is 0.03399158708340033.
# For iteration 11801/50000, the training cost is 0.0021013787996667786.
# For iteration 11801/50000, the test cost is 0.034011438620155925.
# For iteration 11901/50000, the training cost is 0.0020794427765748126.
# For iteration 11901/50000, the test cost is 0.03403403495024719.
# For iteration 12001/50000, the training cost is 0.0020578735695851967.
# For iteration 12001/50000, the test cost is 0.034059299755450634.
# For iteration 12101/50000, the training cost is 0.0020366650060972148.
# For iteration 12101/50000, the test cost is 0.03408715826647588.
# For iteration 12201/50000, the training cost is 0.002015811017387885.
# For iteration 12201/50000, the test cost is 0.034117537234587526.
# For iteration 12301/50000, the training cost is 0.0019953056368638097.
# For iteration 12301/50000, the test cost is 0.03415036490372396.
# For iteration 12401/50000, the training cost is 0.0019751429983424413.
# For iteration 12401/50000, the test cost is 0.03418557098310615.
# For iteration 12501/50000, the training cost is 0.0019553173343623297.
# For iteration 12501/50000, the test cost is 0.03422308662032675.
# For iteration 12601/50000, the training cost is 0.0019358229745217188.
# For iteration 12601/50000, the test cost is 0.03426284437491157.
# For iteration 12701/50000, the training cost is 0.0019166543438451568.
# For iteration 12701/50000, the test cost is 0.03430477819234622.
# For iteration 12801/50000, the training cost is 0.0018978059611775469.
# For iteration 12801/50000, the test cost is 0.034348823378558345.
# For iteration 12901/50000, the training cost is 0.0018792724376053475.
# For iteration 12901/50000, the test cost is 0.03439491657484881.
# For iteration 13001/50000, the training cost is 0.001861048474904124.
# For iteration 13001/50000, the test cost is 0.0344429957332642.
# For iteration 13101/50000, the training cost is 0.001843128864012475.
# For iteration 13101/50000, the test cost is 0.034493000092401443.
# For iteration 13201/50000, the training cost is 0.0018255084835314193.
# For iteration 13201/50000, the test cost is 0.0345448701536394.
# For iteration 13301/50000, the training cost is 0.0018081822982492332.
# For iteration 13301/50000, the test cost is 0.034598547657788345.
# For iteration 13401/50000, the training cost is 0.0017911453576909275.
# For iteration 13401/50000, the test cost is 0.03465397556215103.
# For iteration 13501/50000, the training cost is 0.0017743927946923053.
# For iteration 13501/50000, the test cost is 0.0347110980179874.
# For iteration 13601/50000, the training cost is 0.00175791982399784.
# For iteration 13601/50000, the test cost is 0.0347698603483776.
# For iteration 13701/50000, the training cost is 0.0017417217408823799.
# For iteration 13701/50000, the test cost is 0.03483020902647405.
# For iteration 13801/50000, the training cost is 0.0017257939197957586.
# For iteration 13801/50000, the test cost is 0.034892091654138355.
# For iteration 13901/50000, the training cost is 0.0017101318130304918.
# For iteration 13901/50000, the test cost is 0.03495545694095463.
# For iteration 14001/50000, the training cost is 0.0016947309494117246.
# For iteration 14001/50000, the test cost is 0.035020254683613736.
# For iteration 14101/50000, the training cost is 0.001679586933009278.
# For iteration 14101/50000, the test cost is 0.035086435745661386.
# For iteration 14201/50000, the training cost is 0.0016646954418713532.
# For iteration 14201/50000, the test cost is 0.035153952037604276.
# For iteration 14301/50000, the training cost is 0.0016500522267795914.
# For iteration 14301/50000, the test cost is 0.03522275649736816.
# For iteration 14401/50000, the training cost is 0.0016356531100250348.
# For iteration 14401/50000, the test cost is 0.03529280307110114.
# For iteration 14501/50000, the training cost is 0.001621493984204688.
# For iteration 14501/50000, the test cost is 0.03536404669431723.
# For iteration 14601/50000, the training cost is 0.001607570811038401.
# For iteration 14601/50000, the test cost is 0.035436443273373114.
# For iteration 14701/50000, the training cost is 0.0015938796202055463.
# For iteration 14701/50000, the test cost is 0.03550994966727363.
# For iteration 14801/50000, the training cost is 0.0015804165082013745.
# For iteration 14801/50000, the test cost is 0.035584523669799056.
# For iteration 14901/50000, the training cost is 0.0015671776372125914.
# For iteration 14901/50000, the test cost is 0.035660123991949545.
# For iteration 15001/50000, the training cost is 0.0015541592340117818.
# For iteration 15001/50000, the test cost is 0.03573671024470107.
# For iteration 15101/50000, the training cost is 0.0015413575888705915.
# For iteration 15101/50000, the test cost is 0.035814242922067474.
# For iteration 15201/50000, the training cost is 0.0015287690544910503.
# For iteration 15201/50000, the test cost is 0.035892683384461874.
# For iteration 15301/50000, the training cost is 0.0015163900449549634.
# For iteration 15301/50000, the test cost is 0.03597199384235593.
# For iteration 15401/50000, the training cost is 0.0015042170346909133.
# For iteration 15401/50000, the test cost is 0.0360521373402273.
# For iteration 15501/50000, the training cost is 0.0014922465574588072.
# For iteration 15501/50000, the test cost is 0.03613307774079421.
# For iteration 15601/50000, the training cost is 0.001480475205351233.
# For iteration 15601/50000, the test cost is 0.036214779709528674.
# For iteration 15701/50000, the training cost is 0.0014688996278119527.
# For iteration 15701/50000, the test cost is 0.036297208699447116.
# For iteration 15801/50000, the training cost is 0.0014575165306706173.
# For iteration 15801/50000, the test cost is 0.0363803309361705.
# For iteration 15901/50000, the training cost is 0.0014463226751939263.
# For iteration 15901/50000, the test cost is 0.03646411340325145.
# For iteration 16001/50000, the training cost is 0.0014353148771526843.
# For iteration 16001/50000, the test cost is 0.03654852382776229.
# For iteration 16101/50000, the training cost is 0.0014244900059045258.
# For iteration 16101/50000, the test cost is 0.036633530666140196.
# For iteration 16201/50000, the training cost is 0.0014138449834921421.
# For iteration 16201/50000, the test cost is 0.03671910309028521.
# For iteration 16301/50000, the training cost is 0.0014033767837566163.
# For iteration 16301/50000, the test cost is 0.03680521097390629.
# For iteration 16401/50000, the training cost is 0.0013930824314657402.
# For iteration 16401/50000, the test cost is 0.03689182487911116.
# For iteration 16501/50000, the training cost is 0.0013829590014569988.
# For iteration 16501/50000, the test cost is 0.03697891604323544.
# For iteration 16601/50000, the training cost is 0.0013730036177949112.
# For iteration 16601/50000, the test cost is 0.03706645636590822.
# For iteration 16701/50000, the training cost is 0.0013632134529425835.
# For iteration 16701/50000, the test cost is 0.03715441839634803.
# For iteration 16801/50000, the training cost is 0.001353585726947276.
# For iteration 16801/50000, the test cost is 0.037242775320886976.
# For iteration 16901/50000, the training cost is 0.0013441177066396022.
# For iteration 16901/50000, the test cost is 0.03733150095071765.
# For iteration 17001/50000, the training cost is 0.0013348067048461509.
# For iteration 17001/50000, the test cost is 0.03742056970986006.
# For iteration 17101/50000, the training cost is 0.0013256500796155117.
# For iteration 17101/50000, the test cost is 0.03750995662334421.
# For iteration 17201/50000, the training cost is 0.0013166452334571806.
# For iteration 17201/50000, the test cost is 0.03759963730560485.
# For iteration 17301/50000, the training cost is 0.0013077896125933965.
# For iteration 17301/50000, the test cost is 0.03768958794908434.
# For iteration 17401/50000, the training cost is 0.001299080706223407.
# For iteration 17401/50000, the test cost is 0.03777978531303969.
# For iteration 17501/50000, the training cost is 0.001290516045800337.
# For iteration 17501/50000, the test cost is 0.03787020671255238.
# For iteration 17601/50000, the training cost is 0.0012820932043199828.
# For iteration 17601/50000, the test cost is 0.03796083000773369.
# For iteration 17701/50000, the training cost is 0.0012738097956217986.
# For iteration 17701/50000, the test cost is 0.03805163359312617.
# For iteration 17801/50000, the training cost is 0.0012656634737014934.
# For iteration 17801/50000, the test cost is 0.03814259638729461.
# For iteration 17901/50000, the training cost is 0.0012576519320352075.
# For iteration 17901/50000, the test cost is 0.038233697822605134.
# For iteration 18001/50000, the training cost is 0.0012497729029152134.
# For iteration 18001/50000, the test cost is 0.03832491783518865.
# For iteration 18101/50000, the training cost is 0.001242024156796578.
# For iteration 18101/50000, the test cost is 0.03841623685508492.
# For iteration 18201/50000, the training cost is 0.001234403501654968.
# For iteration 18201/50000, the test cost is 0.03850763579656502.
# For iteration 18301/50000, the training cost is 0.0012269087823552382.
# For iteration 18301/50000, the test cost is 0.03859909604862782.
# For iteration 18401/50000, the training cost is 0.0012195378800306089.
# For iteration 18401/50000, the test cost is 0.03869059946566925.
# For iteration 18501/50000, the training cost is 0.0012122887114722955.
# For iteration 18501/50000, the test cost is 0.038782128358319436.
# For iteration 18601/50000, the training cost is 0.0012051592285294468.
# For iteration 18601/50000, the test cost is 0.038873665484446214.
# For iteration 18701/50000, the training cost is 0.0011981474175191526.
# For iteration 18701/50000, the test cost is 0.038965194040321054.
# For iteration 18801/50000, the training cost is 0.0011912512986464163.
# For iteration 18801/50000, the test cost is 0.03905669765194618.
# For iteration 18901/50000, the training cost is 0.0011844689254337933.
# For iteration 18901/50000, the test cost is 0.039148160366536795.
# For iteration 19001/50000, the training cost is 0.0011777983841607653.
# For iteration 19001/50000, the test cost is 0.03923956664416027.
# For iteration 19101/50000, the training cost is 0.0011712377933124159.
# For iteration 19101/50000, the test cost is 0.03933090134952591.
# For iteration 19201/50000, the training cost is 0.0011647853030375304.
# For iteration 19201/50000, the test cost is 0.03942214974392417.
# For iteration 19301/50000, the training cost is 0.0011584390946156125.
# For iteration 19301/50000, the test cost is 0.03951329747731165.
# For iteration 19401/50000, the training cost is 0.0011521973799331242.
# For iteration 19401/50000, the test cost is 0.039604330580542135.
# For iteration 19501/50000, the training cost is 0.0011460584009682806.
# For iteration 19501/50000, the test cost is 0.03969523545773676.
# For iteration 19601/50000, the training cost is 0.0011400204292847415.
# For iteration 19601/50000, the test cost is 0.03978599887879466.
# For iteration 19701/50000, the training cost is 0.0011340817655336678.
# For iteration 19701/50000, the test cost is 0.03987660797204012.
# For iteration 19801/50000, the training cost is 0.0011282407389641958.
# For iteration 19801/50000, the test cost is 0.03996705021700352.
# For iteration 19901/50000, the training cost is 0.0011224957069422316.
# For iteration 19901/50000, the test cost is 0.04005731343733409.
# For iteration 20001/50000, the training cost is 0.0011168450544772237.
# For iteration 20001/50000, the test cost is 0.04014738579384242.
# For iteration 20101/50000, the training cost is 0.0011112871937569637.
# For iteration 20101/50000, the test cost is 0.04023725577767045.
# For iteration 20201/50000, the training cost is 0.0011058205636902086.
# For iteration 20201/50000, the test cost is 0.040326912203586196.
# For iteration 20301/50000, the training cost is 0.001100443629457021.
# For iteration 20301/50000, the test cost is 0.04041634420340107.
# For iteration 20401/50000, the training cost is 0.0010951548820666121.
# For iteration 20401/50000, the test cost is 0.04050554121950892.
# For iteration 20501/50000, the training cost is 0.001089952837922684.
# For iteration 20501/50000, the test cost is 0.04059449299854226.
# For iteration 20601/50000, the training cost is 0.0010848360383960865.
# For iteration 20601/50000, the test cost is 0.040683189585146204.
# For iteration 20701/50000, the training cost is 0.001079803049404643.
# For iteration 20701/50000, the test cost is 0.04077162131586598.
# For iteration 20801/50000, the training cost is 0.0010748524610000023.
# For iteration 20801/50000, the test cost is 0.04085977881314732.
# For iteration 20901/50000, the training cost is 0.0010699828869615822.
# For iteration 20901/50000, the test cost is 0.0409476529794476.
# For iteration 21001/50000, the training cost is 0.0010651929643971853.
# For iteration 21001/50000, the test cost is 0.041035234991454714.
# For iteration 21101/50000, the training cost is 0.0010604813533504375.
# For iteration 21101/50000, the test cost is 0.04112251629441333.
# For iteration 21201/50000, the training cost is 0.001055846736414814.
# For iteration 21201/50000, the test cost is 0.041209488596555176.
# For iteration 21301/50000, the training cost is 0.001051287818354104.
# For iteration 21301/50000, the test cost is 0.04129614386363287.
# For iteration 21401/50000, the training cost is 0.001046803325729404.
# For iteration 21401/50000, the test cost is 0.04138247431355464.
# For iteration 21501/50000, the training cost is 0.0010423920065321763.
# For iteration 21501/50000, the test cost is 0.04146847241111808.
# For iteration 21601/50000, the training cost is 0.0010380526298236852.
# For iteration 21601/50000, the test cost is 0.04155413086284163.
# For iteration 21701/50000, the training cost is 0.0010337839853803929.
# For iteration 21701/50000, the test cost is 0.041639442611891946.
# For iteration 21801/50000, the training cost is 0.001029584883345328.
# For iteration 21801/50000, the test cost is 0.041724400833105475.
# For iteration 21901/50000, the training cost is 0.0010254541538853553.
# For iteration 21901/50000, the test cost is 0.04180899892810269.
# For iteration 22001/50000, the training cost is 0.0010213906468542117.
# For iteration 22001/50000, the test cost is 0.04189323052049203.
# For iteration 22101/50000, the training cost is 0.0010173932314611735.
# For iteration 22101/50000, the test cost is 0.041977089451164795.
# For iteration 22201/50000, the training cost is 0.001013460795945334.
# For iteration 22201/50000, the test cost is 0.04206056977367673.
# For iteration 22301/50000, the training cost is 0.0010095922472553496.
# For iteration 22301/50000, the test cost is 0.042143665749715495.
# For iteration 22401/50000, the training cost is 0.001005786510734588.
# For iteration 22401/50000, the test cost is 0.04222637184465297.
# For iteration 22501/50000, the training cost is 0.0010020425298115628.
# For iteration 22501/50000, the test cost is 0.04230868272318234.
# For iteration 22601/50000, the training cost is 0.0009983592656955772.
# For iteration 22601/50000, the test cost is 0.042390593245032984.
# For iteration 22701/50000, the training cost is 0.000994735697077494.
# For iteration 22701/50000, the test cost is 0.04247209846076954.
# For iteration 22801/50000, the training cost is 0.00099117081983555.
# For iteration 22801/50000, the test cost is 0.042553193607667086.
# For iteration 22901/50000, the training cost is 0.0009876636467461013.
# For iteration 22901/50000, the test cost is 0.04263387410566554.
# For iteration 23001/50000, the training cost is 0.0009842132071992509.
# For iteration 23001/50000, the test cost is 0.042714135553398314.
# For iteration 23101/50000, the training cost is 0.0009808185469192554.
# For iteration 23101/50000, the test cost is 0.04279397372429661.
# For iteration 23201/50000, the training cost is 0.0009774787276896478.
# For iteration 23201/50000, the test cost is 0.04287338456276752.
# For iteration 23301/50000, the training cost is 0.0009741928270829662.
# For iteration 23301/50000, the test cost is 0.042952364180442966.
# For iteration 23401/50000, the training cost is 0.0009709599381950567.
# For iteration 23401/50000, the test cost is 0.04303090885249966.
# For iteration 23501/50000, the training cost is 0.0009677791693838362.
# For iteration 23501/50000, the test cost is 0.043109015014050026.
# For iteration 23601/50000, the training cost is 0.0009646496440124126.
# For iteration 23601/50000, the test cost is 0.043186679256598665.
# For iteration 23701/50000, the training cost is 0.0009615705001966114.
# For iteration 23701/50000, the test cost is 0.043263898324568416.
# For iteration 23801/50000, the training cost is 0.0009585408905566803.
# For iteration 23801/50000, the test cost is 0.04334066911189086.
# For iteration 23901/50000, the training cost is 0.0009555599819732098.
# For iteration 23901/50000, the test cost is 0.04341698865866218.
# For iteration 24001/50000, the training cost is 0.0009526269553471238.
# For iteration 24001/50000, the test cost is 0.0434928541478617.
# For iteration 24101/50000, the training cost is 0.000949741005363753.
# For iteration 24101/50000, the test cost is 0.04356826290213359.
# For iteration 24201/50000, the training cost is 0.0009469013402608574.
# For iteration 24201/50000, the test cost is 0.04364321238062957.
# For iteration 24301/50000, the training cost is 0.0009441071816005596.
# For iteration 24301/50000, the test cost is 0.043717700175912005.
# For iteration 24401/50000, the training cost is 0.000941357764045082.
# For iteration 24401/50000, the test cost is 0.04379172401091575.
# For iteration 24501/50000, the training cost is 0.0009386523351363219.
# For iteration 24501/50000, the test cost is 0.04386528173596799.
# For iteration 24601/50000, the training cost is 0.0009359901550790884.
# For iteration 24601/50000, the test cost is 0.043938371325866137.
# For iteration 24701/50000, the training cost is 0.0009333704965280044.
# For iteration 24701/50000, the test cost is 0.044010990877009465.
# For iteration 24801/50000, the training cost is 0.0009307926443779442.
# For iteration 24801/50000, the test cost is 0.04408313860458889.
# For iteration 24901/50000, the training cost is 0.0009282558955581427.
# For iteration 24901/50000, the test cost is 0.044154812839827716.
# For iteration 25001/50000, the training cost is 0.0009257595588295855.
# For iteration 25001/50000, the test cost is 0.044226012027277294.
# For iteration 25101/50000, the training cost is 0.0009233029545859026.
# For iteration 25101/50000, the test cost is 0.04429673472216441.
# For iteration 25201/50000, the training cost is 0.0009208854146576692.
# For iteration 25201/50000, the test cost is 0.04436697958778931.
# For iteration 25301/50000, the training cost is 0.0009185062821198428.
# For iteration 25301/50000, the test cost is 0.04443674539297449.
# For iteration 25401/50000, the training cost is 0.0009161649111026059.
# For iteration 25401/50000, the test cost is 0.044506031009562665.
# For iteration 25501/50000, the training cost is 0.0009138606666052758.
# For iteration 25501/50000, the test cost is 0.04457483540996292.
# For iteration 25601/50000, the training cost is 0.0009115929243134265.
# For iteration 25601/50000, the test cost is 0.044643157664745005.
# For iteration 25701/50000, the training cost is 0.0009093610704190092.
# For iteration 25701/50000, the test cost is 0.044710996940279975.
# For iteration 25801/50000, the training cost is 0.0009071645014435703.
# For iteration 25801/50000, the test cost is 0.044778352496426824.
# For iteration 25901/50000, the training cost is 0.0009050026240644358.
# For iteration 25901/50000, the test cost is 0.04484522368426387.
# For iteration 26001/50000, the training cost is 0.0009028748549437216.
# For iteration 26001/50000, the test cost is 0.04491160994386501.
# For iteration 26101/50000, the training cost is 0.0009007806205603914.
# For iteration 26101/50000, the test cost is 0.04497751080211845.
# For iteration 26201/50000, the training cost is 0.0008987193570450097.
# For iteration 26201/50000, the test cost is 0.04504292587058973.
# For iteration 26301/50000, the training cost is 0.0008966905100173131.
# For iteration 26301/50000, the test cost is 0.045107854843424736.
# For iteration 26401/50000, the training cost is 0.0008946935344265182.
# For iteration 26401/50000, the test cost is 0.045172297495295326.
# For iteration 26501/50000, the training cost is 0.0008927278943943426.
# For iteration 26501/50000, the test cost is 0.045236253679384116.
# For iteration 26601/50000, the training cost is 0.0008907930630605948.
# For iteration 26601/50000, the test cost is 0.04529972332541038.
# For iteration 26701/50000, the training cost is 0.0008888885224314697.
# For iteration 26701/50000, the test cost is 0.04536270643769342.
# For iteration 26801/50000, the training cost is 0.0008870137632302843.
# For iteration 26801/50000, the test cost is 0.045425203093255366.
# For iteration 26901/50000, the training cost is 0.0008851682847508084.
# For iteration 26901/50000, the test cost is 0.045487213439960685.
# For iteration 27001/50000, the training cost is 0.0008833515947130227.
# For iteration 27001/50000, the test cost is 0.045548737694693135.
# For iteration 27101/50000, the training cost is 0.0008815632091213138.
# For iteration 27101/50000, the test cost is 0.04560977614156834.
# For iteration 27201/50000, the training cost is 0.0008798026521250777.
# For iteration 27201/50000, the test cost is 0.045670329130182555.
# For iteration 27301/50000, the training cost is 0.0008780694558816218.
# For iteration 27301/50000, the test cost is 0.04573039707389607.
# For iteration 27401/50000, the training cost is 0.0008763631604214005.
# For iteration 27401/50000, the test cost is 0.04578998044814994.
# For iteration 27501/50000, the training cost is 0.0008746833135155533.
# For iteration 27501/50000, the test cost is 0.04584907978881899.
# For iteration 27601/50000, the training cost is 0.0008730294705455853.
# For iteration 27601/50000, the test cost is 0.04590769569059394.
# For iteration 27701/50000, the training cost is 0.000871401194375357.
# For iteration 27701/50000, the test cost is 0.045965828805400226.
# For iteration 27801/50000, the training cost is 0.000869798055225116.
# For iteration 27801/50000, the test cost is 0.04602347984084472.
# For iteration 27901/50000, the training cost is 0.0008682196305476893.
# For iteration 27901/50000, the test cost is 0.046080649558696465.
# For iteration 28001/50000, the training cost is 0.0008666655049068163.
# For iteration 28001/50000, the test cost is 0.04613733877339675.
# For iteration 28101/50000, the training cost is 0.0008651352698574604.
# For iteration 28101/50000, the test cost is 0.04619354835060035.
# For iteration 28201/50000, the training cost is 0.00086362852382811.
# For iteration 28201/50000, the test cost is 0.04624927920574444.
# For iteration 28301/50000, the training cost is 0.0008621448720051989.
# For iteration 28301/50000, the test cost is 0.04630453230264909.
# For iteration 28401/50000, the training cost is 0.0008606839262192715.
# For iteration 28401/50000, the test cost is 0.04635930865214389.
# For iteration 28501/50000, the training cost is 0.0008592453048332312.
# For iteration 28501/50000, the test cost is 0.04641360931072415.
# For iteration 28601/50000, the training cost is 0.0008578286326324334.
# For iteration 28601/50000, the test cost is 0.0464674353792338.
# For iteration 28701/50000, the training cost is 0.0008564335407165213.
# For iteration 28701/50000, the test cost is 0.046520788001575455.
# For iteration 28801/50000, the training cost is 0.0008550596663932309.
# For iteration 28801/50000, the test cost is 0.04657366836344689.
# For iteration 28901/50000, the training cost is 0.0008537066530738816.
# For iteration 28901/50000, the test cost is 0.04662607769110372.
# For iteration 29001/50000, the training cost is 0.0008523741501707024.
# For iteration 29001/50000, the test cost is 0.0466780172501469.
# For iteration 29101/50000, the training cost is 0.0008510618129957875.
# For iteration 29101/50000, the test cost is 0.04672948834433643.
# For iteration 29201/50000, the training cost is 0.0008497693026618344.
# For iteration 29201/50000, the test cost is 0.046780492314428226.
# For iteration 29301/50000, the training cost is 0.0008484962859845386.
# For iteration 29301/50000, the test cost is 0.046831030537035946.
# For iteration 29401/50000, the training cost is 0.0008472424353865974.
# For iteration 29401/50000, the test cost is 0.04688110442351671.
# For iteration 29501/50000, the training cost is 0.0008460074288033637.
# For iteration 29501/50000, the test cost is 0.04693071541887929.
# For iteration 29601/50000, the training cost is 0.0008447909495900718.
# For iteration 29601/50000, the test cost is 0.046979865000715375.
# For iteration 29701/50000, the training cost is 0.0008435926864306223.
# For iteration 29701/50000, the test cost is 0.04702855467815362.
# For iteration 29801/50000, the training cost is 0.0008424123332479092.
# For iteration 29801/50000, the test cost is 0.047076785990835424.
# For iteration 29901/50000, the training cost is 0.000841249589115662.
# For iteration 29901/50000, the test cost is 0.04712456050791135.
# For iteration 30001/50000, the training cost is 0.0008401041581717493.
# For iteration 30001/50000, the test cost is 0.04717187982706085.
# For iteration 30101/50000, the training cost is 0.0008389757495329396.
# For iteration 30101/50000, the test cost is 0.047218745573529994.
# For iteration 30201/50000, the training cost is 0.0008378640772111885.
# For iteration 30201/50000, the test cost is 0.04726515939919189.
# For iteration 30301/50000, the training cost is 0.000836768860031146.
# For iteration 30301/50000, the test cost is 0.04731112298162605.
# For iteration 30401/50000, the training cost is 0.0008356898215492556.
# For iteration 30401/50000, the test cost is 0.04735663802321722.
# For iteration 30501/50000, the training cost is 0.0008346266899740793.
# For iteration 30501/50000, the test cost is 0.04740170625027425.
# For iteration 30601/50000, the training cost is 0.0008335791980880115.
# For iteration 30601/50000, the test cost is 0.04744632941216687.
# For iteration 30701/50000, the training cost is 0.0008325470831703408.
# For iteration 30701/50000, the test cost is 0.04749050928048182.
# For iteration 30801/50000, the training cost is 0.0008315300869214963.
# For iteration 30801/50000, the test cost is 0.04753424764819653.
# For iteration 30901/50000, the training cost is 0.0008305279553887411.
# For iteration 30901/50000, the test cost is 0.04757754632887161.
# For iteration 31001/50000, the training cost is 0.0008295404388929445.
# For iteration 31001/50000, the test cost is 0.04762040715585978.
# For iteration 31101/50000, the training cost is 0.0008285672919567137.
# For iteration 31101/50000, the test cost is 0.04766283198153191.
# For iteration 31201/50000, the training cost is 0.00082760827323364.
# For iteration 31201/50000, the test cost is 0.04770482267652181.
# For iteration 31301/50000, the training cost is 0.0008266631454387927.
# For iteration 31301/50000, the test cost is 0.047746381128984994.
# For iteration 31401/50000, the training cost is 0.0008257316752803967.
# For iteration 31401/50000, the test cost is 0.04778750924387514.
# For iteration 31501/50000, the training cost is 0.0008248136333925914.
# For iteration 31501/50000, the test cost is 0.04782820894223724.
# For iteration 31601/50000, the training cost is 0.0008239087942694087.
# For iteration 31601/50000, the test cost is 0.04786848216051366.
# For iteration 31701/50000, the training cost is 0.0008230169361997524.
# For iteration 31701/50000, the test cost is 0.04790833084986874.
# For iteration 31801/50000, the training cost is 0.0008221378412036022.
# For iteration 31801/50000, the test cost is 0.04794775697552596.
# For iteration 31901/50000, the training cost is 0.0008212712949691636.
# For iteration 31901/50000, the test cost is 0.047986762516121356.
# For iteration 32001/50000, the training cost is 0.0008204170867911915.
# For iteration 32001/50000, the test cost is 0.04802534946307069.
# For iteration 32101/50000, the training cost is 0.000819575009510261.
# For iteration 32101/50000, the test cost is 0.04806351981995129.
# For iteration 32201/50000, the training cost is 0.000818744859453094.
# For iteration 32201/50000, the test cost is 0.04810127560189762.
# For iteration 32301/50000, the training cost is 0.0008179264363738954.
# For iteration 32301/50000, the test cost is 0.04813861883500946.
# For iteration 32401/50000, the training cost is 0.0008171195433967047.
# For iteration 32401/50000, the test cost is 0.0481755515557759.
# For iteration 32501/50000, the training cost is 0.0008163239869586396.
# For iteration 32501/50000, the test cost is 0.04821207581051057.
# For iteration 32601/50000, the training cost is 0.0008155395767541637.
# For iteration 32601/50000, the test cost is 0.04824819365479951.
# For iteration 32701/50000, the training cost is 0.000814766125680264.
# For iteration 32701/50000, the test cost is 0.048283907152963886.
# For iteration 32801/50000, the training cost is 0.0008140034497825516.
# For iteration 32801/50000, the test cost is 0.04831921837753263.
# For iteration 32901/50000, the training cost is 0.0008132513682022951.
# For iteration 32901/50000, the test cost is 0.04835412940872844.
# For iteration 33001/50000, the training cost is 0.0008125097031243088.
# For iteration 33001/50000, the test cost is 0.04838864233396608.
# For iteration 33101/50000, the training cost is 0.0008117782797257019.
# For iteration 33101/50000, the test cost is 0.04842275924736163.
# For iteration 33201/50000, the training cost is 0.0008110569261255937.
# For iteration 33201/50000, the test cost is 0.048456482249253224.
# For iteration 33301/50000, the training cost is 0.0008103454733355443.
# For iteration 33301/50000, the test cost is 0.04848981344573377.
# For iteration 33401/50000, the training cost is 0.0008096437552108889.
# For iteration 33401/50000, the test cost is 0.04852275494819397.
# For iteration 33501/50000, the training cost is 0.0008089516084028981.
# For iteration 33501/50000, the test cost is 0.048555308872877116.
# For iteration 33601/50000, the training cost is 0.000808268872311713.
# For iteration 33601/50000, the test cost is 0.04858747734044222.
# For iteration 33701/50000, the training cost is 0.0008075953890400878.
# For iteration 33701/50000, the test cost is 0.04861926247554145.
# For iteration 33801/50000, the training cost is 0.0008069310033479059.
# For iteration 33801/50000, the test cost is 0.04865066640640361.
# For iteration 33901/50000, the training cost is 0.0008062755626074567.
# For iteration 33901/50000, the test cost is 0.048681691264430595.
# For iteration 34001/50000, the training cost is 0.0008056289167594949.
# For iteration 34001/50000, the test cost is 0.048712339183802696.
# For iteration 34101/50000, the training cost is 0.0008049909182699892.
# For iteration 34101/50000, the test cost is 0.04874261230109252.
# For iteration 34201/50000, the training cost is 0.0008043614220876375.
# For iteration 34201/50000, the test cost is 0.04877251275489024.
# For iteration 34301/50000, the training cost is 0.0008037402856020992.
# For iteration 34301/50000, the test cost is 0.04880204268543646.
# For iteration 34401/50000, the training cost is 0.0008031273686028821.
# For iteration 34401/50000, the test cost is 0.04883120423426592.
# For iteration 34501/50000, the training cost is 0.0008025225332389971.
# For iteration 34501/50000, the test cost is 0.04885999954385715.
# For iteration 34601/50000, the training cost is 0.000801925643979203.
# For iteration 34601/50000, the test cost is 0.048888430757294966.
# For iteration 34701/50000, the training cost is 0.0008013365675730349.
# For iteration 34701/50000, the test cost is 0.04891650001793728.
# For iteration 34801/50000, the training cost is 0.0008007551730123356.
# For iteration 34801/50000, the test cost is 0.04894420946909358.
# For iteration 34901/50000, the training cost is 0.0008001813314936082.
# For iteration 34901/50000, the test cost is 0.048971561253709744.
# For iteration 35001/50000, the training cost is 0.0007996149163808388.
# For iteration 35001/50000, the test cost is 0.048998557514061465.
# For iteration 35101/50000, the training cost is 0.0007990558031690656.
# For iteration 35101/50000, the test cost is 0.04902520039145593.
# For iteration 35201/50000, the training cost is 0.0007985038694485101.
# For iteration 35201/50000, the test cost is 0.049051492025940543.
# For iteration 35301/50000, the training cost is 0.0007979589948693005.
# For iteration 35301/50000, the test cost is 0.049077434556019775.
# For iteration 35401/50000, the training cost is 0.0007974210611068165.
# ...
# For iteration 38201/50000, the test cost is 0.04968740659641523.
# For iteration 38301/50000, the training cost is 0.0007843737032912605.
# For iteration 38301/50000, the test cost is 0.04970385303284542.
# For iteration 38401/50000, the training cost is 0.0007839977497627333.
# For iteration 38401/50000, the test cost is 0.04972001465395833.
# For iteration 38501/50000, the training cost is 0.0007836259089058911.
# For iteration 38501/50000, the test cost is 0.04973589343755307.
# For iteration 38601/50000, the training cost is 0.0007832581119786317.
# For iteration 38601/50000, the test cost is 0.04975149135393085.
# For iteration 38701/50000, the training cost is 0.0007828942913956368.
# For iteration 38701/50000, the test cost is 0.04976681036579265.
# For iteration 38801/50000, the training cost is 0.0007825343807088646.
# For iteration 38801/50000, the test cost is 0.049781852428145305.
# For iteration 38901/50000, the training cost is 0.000782178314588394.
# For iteration 38901/50000, the test cost is 0.049796619488207725.
# For iteration 39001/50000, the training cost is 0.000781826028803654.
# For iteration 39001/50000, the test cost is 0.04981111348532251.
# For iteration 39101/50000, the training cost is 0.0007814774602048982.
# For iteration 39101/50000, the test cost is 0.04982533635086932.
# For iteration 39201/50000, the training cost is 0.0007811325467050447.
# For iteration 39201/50000, the test cost is 0.04983929000818474.
# For iteration 39301/50000, the training cost is 0.0007807912272616971.
# For iteration 39301/50000, the test cost is 0.04985297637248104.
# For iteration 39401/50000, the training cost is 0.0007804534418597049.
# For iteration 39401/50000, the test cost is 0.04986639735077182.
# For iteration 39501/50000, the training cost is 0.0007801191314937659.
# For iteration 39501/50000, the test cost is 0.04987955484179879.
# For iteration 39601/50000, the training cost is 0.000779788238151497.
# For iteration 39601/50000, the test cost is 0.049892450735962324.
# For iteration 39701/50000, the training cost is 0.0007794607047966783.
# For iteration 39701/50000, the test cost is 0.049905086915255296.
# For iteration 39801/50000, the training cost is 0.0007791364753528394.
# For iteration 39801/50000, the test cost is 0.04991746525319881.
# For iteration 39901/50000, the training cost is 0.0007788154946871322.
# For iteration 39901/50000, the test cost is 0.049929587614782056.
# For iteration 40001/50000, the training cost is 0.000778497708594418.
# For iteration 40001/50000, the test cost is 0.04994145585640364.
# For iteration 40101/50000, the training cost is 0.0007781830637816832.
# For iteration 40101/50000, the test cost is 0.04995307182581711.
# For iteration 40201/50000, the training cost is 0.000777871507852678.
# For iteration 40201/50000, the test cost is 0.04996443736207773.
# For iteration 40301/50000, the training cost is 0.0007775629892927944.
# For iteration 40301/50000, the test cost is 0.049975554295492775.
# For iteration 40401/50000, the training cost is 0.0007772574574542899.
# For iteration 40401/50000, the test cost is 0.04998642444757479.
# For iteration 40501/50000, the training cost is 0.0007769548625416474.
# For iteration 40501/50000, the test cost is 0.04999704963099545.
# For iteration 40601/50000, the training cost is 0.0007766551555972586.
# For iteration 40601/50000, the test cost is 0.05000743164954425.
# For iteration 40701/50000, the training cost is 0.000776358288487315.
# For iteration 40701/50000, the test cost is 0.05001757229808804.
# For iteration 40801/50000, the training cost is 0.0007760642138879545.
# For iteration 40801/50000, the test cost is 0.050027473362533.
# For iteration 40901/50000, the training cost is 0.0007757728852716054.
# For iteration 40901/50000, the test cost is 0.05003713661978962.
# For iteration 41001/50000, the training cost is 0.0007754842568936235.
# For iteration 41001/50000, the test cost is 0.050046563837739144.
# For iteration 41101/50000, the training cost is 0.0007751982837790822.
# For iteration 41101/50000, the test cost is 0.05005575677520351.
# For iteration 41201/50000, the training cost is 0.0007749149217098326.
# For iteration 41201/50000, the test cost is 0.05006471718191458.
# For iteration 41301/50000, the training cost is 0.0007746341272117735.
# For iteration 41301/50000, the test cost is 0.05007344679848917.
# For iteration 41401/50000, the training cost is 0.0007743558575423252.
# For iteration 41401/50000, the test cost is 0.0500819473564031.
# For iteration 41501/50000, the training cost is 0.0007740800706781076.
# For iteration 41501/50000, the test cost is 0.050090220577968546.
# For iteration 41601/50000, the training cost is 0.0007738067253028682.
# For iteration 41601/50000, the test cost is 0.05009826817631351.
# For iteration 41701/50000, the training cost is 0.0007735357807955361.
# For iteration 41701/50000, the test cost is 0.050106091855362356.
# For iteration 41801/50000, the training cost is 0.0007732671972185575.
# For iteration 41801/50000, the test cost is 0.05011369330981856.
# For iteration 41901/50000, the training cost is 0.0007730009353064009.
# For iteration 41901/50000, the test cost is 0.05012107422514994.
# For iteration 42001/50000, the training cost is 0.0007727369564541958.
# For iteration 42001/50000, the test cost is 0.050128236277574525.
# For iteration 42101/50000, the training cost is 0.0007724752227066787.
# For iteration 42101/50000, the test cost is 0.050135181134048704.
# For iteration 42201/50000, the training cost is 0.000772215696747212.
# For iteration 42201/50000, the test cost is 0.050141910452256654.
# For iteration 42301/50000, the training cost is 0.0007719583418870733.
# For iteration 42301/50000, the test cost is 0.05014842588060239.
# For iteration 42401/50000, the training cost is 0.0007717031220548524.
# For iteration 42401/50000, the test cost is 0.050154729058201925.
# For iteration 42501/50000, the training cost is 0.0007714500017860956.
# For iteration 42501/50000, the test cost is 0.05016082161487845.
# For iteration 42601/50000, the training cost is 0.0007711989462130706.
# For iteration 42601/50000, the test cost is 0.05016670517115749.
# For iteration 42701/50000, the training cost is 0.0007709499210547286.
# For iteration 42701/50000, the test cost is 0.05017238133826542.
# For iteration 42801/50000, the training cost is 0.000770702892606833.
# For iteration 42801/50000, the test cost is 0.05017785171812757.
# For iteration 42901/50000, the training cost is 0.0007704578277322626.
# For iteration 42901/50000, the test cost is 0.05018311790336891.
# For iteration 43001/50000, the training cost is 0.0007702146938514447.
# For iteration 43001/50000, the test cost is 0.05018818147731532.
# For iteration 43101/50000, the training cost is 0.0007699734589329931.
# For iteration 43101/50000, the test cost is 0.05019304401399682.
# For iteration 43201/50000, the training cost is 0.0007697340914844715.
# For iteration 43201/50000, the test cost is 0.05019770707815236.
# For iteration 43301/50000, the training cost is 0.000769496560543323.
# For iteration 43301/50000, the test cost is 0.050202172225234126.
# For iteration 43401/50000, the training cost is 0.0007692608356679732.
# For iteration 43401/50000, the test cost is 0.05020644100141554.
# For iteration 43501/50000, the training cost is 0.0007690268869290163.
# For iteration 43501/50000, the test cost is 0.050210514943598426.
# For iteration 43601/50000, the training cost is 0.0007687946849006637.
# For iteration 43601/50000, the test cost is 0.050214395579422665.
# For iteration 43701/50000, the training cost is 0.0007685642006521925.
# For iteration 43701/50000, the test cost is 0.05021808442727543.
# For iteration 43801/50000, the training cost is 0.0007683354057396815.
# For iteration 43801/50000, the test cost is 0.05022158299630432.
# For iteration 43901/50000, the training cost is 0.0007681082721977657.
# For iteration 43901/50000, the test cost is 0.05022489278642775.
# For iteration 44001/50000, the training cost is 0.0007678827725316427.
# For iteration 44001/50000, the test cost is 0.05022801528835032.
# For iteration 44101/50000, the training cost is 0.0007676588797090854.
# For iteration 44101/50000, the test cost is 0.05023095198357548.
# For iteration 44201/50000, the training cost is 0.0007674365671526841.
# For iteration 44201/50000, the test cost is 0.050233704344422675.
# For iteration 44301/50000, the training cost is 0.0007672158087322363.
# For iteration 44301/50000, the test cost is 0.05023627383404237.
# For iteration 44401/50000, the training cost is 0.0007669965787571523.
# For iteration 44401/50000, the test cost is 0.0502386619064345.
# For iteration 44501/50000, the training cost is 0.0007667788519690888.
# For iteration 44501/50000, the test cost is 0.05024087000646593.
# For iteration 44601/50000, the training cost is 0.0007665626035346965.
# For iteration 44601/50000, the test cost is 0.05024289956989001.
# For iteration 44701/50000, the training cost is 0.0007663478090384057.
# For iteration 44701/50000, the test cost is 0.05024475202336642.
# For iteration 44801/50000, the training cost is 0.0007661344444754798.
# For iteration 44801/50000, the test cost is 0.05024642878448198.
# For iteration 44901/50000, the training cost is 0.0007659224862450136.
# For iteration 44901/50000, the test cost is 0.050247931261772745.
# For iteration 45001/50000, the training cost is 0.0007657119111432168.
# For iteration 45001/50000, the test cost is 0.05024926085474547.
# For iteration 45101/50000, the training cost is 0.0007655026963566707.
# For iteration 45101/50000, the test cost is 0.050250418953901976.
# For iteration 45201/50000, the training cost is 0.000765294819455785.
# For iteration 45201/50000, the test cost is 0.05025140694076191.
# For iteration 45301/50000, the training cost is 0.000765088258388352.
# For iteration 45301/50000, the test cost is 0.05025222618788809.
# For iteration 45401/50000, the training cost is 0.0007648829914731523.
# For iteration 45401/50000, the test cost is 0.05025287805891173.
# For iteration 45501/50000, the training cost is 0.0007646789973937634.
# For iteration 45501/50000, the test cost is 0.05025336390855811.
# For iteration 45601/50000, the training cost is 0.0007644762551923835.
# For iteration 45601/50000, the test cost is 0.050253685082673756.
# For iteration 45701/50000, the training cost is 0.0007642747442638086.
# For iteration 45701/50000, the test cost is 0.05025384291825301.
# For iteration 45801/50000, the training cost is 0.000764074444349512.
# For iteration 45801/50000, the test cost is 0.050253838743466256.
# For iteration 45901/50000, the training cost is 0.0007638753355317713.
# For iteration 45901/50000, the test cost is 0.050253673877688906.
# For iteration 46001/50000, the training cost is 0.0007636773982279819.
# For iteration 46001/50000, the test cost is 0.050253349631529456.
# For iteration 46101/50000, the training cost is 0.0007634806131849842.
# For iteration 46101/50000, the test cost is 0.05025286730685988.
# For iteration 46201/50000, the training cost is 0.0007632849614735324.
# For iteration 46201/50000, the test cost is 0.05025222819684499.
# For iteration 46301/50000, the training cost is 0.0007630904244828382.
# For iteration 46301/50000, the test cost is 0.05025143358597414.
# For iteration 46401/50000, the training cost is 0.0007628969839152069.
# For iteration 46401/50000, the test cost is 0.0502504847500917.
# For iteration 46501/50000, the training cost is 0.0007627046217807971.
# For iteration 46501/50000, the test cost is 0.05024938295642823.
# For iteration 46601/50000, the training cost is 0.0007625133203923977.
# For iteration 46601/50000, the test cost is 0.05024812946363349.
# For iteration 46701/50000, the training cost is 0.0007623230623603525.
# For iteration 46701/50000, the test cost is 0.050246725521808415.
# For iteration 46801/50000, the training cost is 0.0007621338305875719.
# For iteration 46801/50000, the test cost is 0.050245172372537936.
# For iteration 46901/50000, the training cost is 0.0007619456082645905.
# For iteration 46901/50000, the test cost is 0.05024347124892565.
# For iteration 47001/50000, the training cost is 0.000761758378864715.
# For iteration 47001/50000, the test cost is 0.05024162337562519.
# For iteration 47101/50000, the training cost is 0.0007615721261392998.
# For iteration 47101/50000, the test cost is 0.05023962996887677.
# For iteration 47201/50000, the training cost is 0.0007613868341130218.
# For iteration 47201/50000, the test cost is 0.05023749223654085.
# For iteration 47301/50000, the training cost is 0.0007612024870793304.
# For iteration 47301/50000, the test cost is 0.05023521137813198.
# For iteration 47401/50000, the training cost is 0.0007610190695958932.
# For iteration 47401/50000, the test cost is 0.05023278858485565.
# For iteration 47501/50000, the training cost is 0.0007608365664801567.
# For iteration 47501/50000, the test cost is 0.05023022503964319.
# For iteration 47601/50000, the training cost is 0.0007606549628049742.
# For iteration 47601/50000, the test cost is 0.05022752191718754.
# For iteration 47701/50000, the training cost is 0.0007604742438942949.
# For iteration 47701/50000, the test cost is 0.05022468038397953.
# For iteration 47801/50000, the training cost is 0.0007602943953189781.
# For iteration 47801/50000, the test cost is 0.05022170159834372.
# For iteration 47901/50000, the training cost is 0.0007601154028925953.
# For iteration 47901/50000, the test cost is 0.050218586710476944.
# For iteration 48001/50000, the training cost is 0.0007599372526673599.
# For iteration 48001/50000, the test cost is 0.050215336862483084.
# For iteration 48101/50000, the training cost is 0.0007597599309301248.
# For iteration 48101/50000, the test cost is 0.05021195318841158.
# For iteration 48201/50000, the training cost is 0.0007595834241984041.
# For iteration 48201/50000, the test cost is 0.05020843681429513.
# For iteration 48301/50000, the training cost is 0.000759407719216531.
# For iteration 48301/50000, the test cost is 0.05020478885818638.
# For iteration 48401/50000, the training cost is 0.0007592328029518041.
# For iteration 48401/50000, the test cost is 0.05020101043019677.
# For iteration 48501/50000, the training cost is 0.0007590586625907409.
# For iteration 48501/50000, the test cost is 0.05019710263253425.
# For iteration 48601/50000, the training cost is 0.0007588852855354297.
# For iteration 48601/50000, the test cost is 0.05019306655954156.
# For iteration 48701/50000, the training cost is 0.0007587126593998443.
# For iteration 48701/50000, the test cost is 0.05018890329773509.
# For iteration 48801/50000, the training cost is 0.000758540772006303.
# For iteration 48801/50000, the test cost is 0.05018461392584323.
# For iteration 48901/50000, the training cost is 0.0007583696113819757.
# For iteration 48901/50000, the test cost is 0.05018019951484534.
# For iteration 49001/50000, the training cost is 0.0007581991657554224.
# For iteration 49001/50000, the test cost is 0.05017566112801087.
# For iteration 49101/50000, the training cost is 0.0007580294235531938.
# For iteration 49101/50000, the test cost is 0.05017099982093851.
# For iteration 49201/50000, the training cost is 0.0007578603733965183.
# For iteration 49201/50000, the test cost is 0.05016621664159497.
# For iteration 49301/50000, the training cost is 0.0007576920040980275.
# For iteration 49301/50000, the test cost is 0.0501613126303548.
# For iteration 49401/50000, the training cost is 0.0007575243046585206.
# For iteration 49401/50000, the test cost is 0.05015628882004037.
# For iteration 49501/50000, the training cost is 0.0007573572642637923.
# For iteration 49501/50000, the test cost is 0.05015114623596078.
# For iteration 49601/50000, the training cost is 0.0007571908722815392.
# For iteration 49601/50000, the test cost is 0.05014588589595168.
# For iteration 49701/50000, the training cost is 0.0007570251182583002.
# For iteration 49701/50000, the test cost is 0.05014050881041505.
# For iteration 49801/50000, the training cost is 0.0007568599919164167.
# For iteration 49801/50000, the test cost is 0.05013501598235996.
# For iteration 49901/50000, the training cost is 0.0007566954831511135.
# For iteration 49901/50000, the test cost is 0.050129408407441164.

# %%
# putting the learning curve to show the overfitting issue of the model
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(J_history, label='Training')
axs[0].plot(test_J_history, label='Test')
axs[0].set_xlabel('Iterations')
axs[0].set_ylabel('Cost')
axs[0].set_title('Cost vs. Iterations')
axs[0].legend()

axs[1].plot(J_history[5000:], label='Training')
axs[1].plot(test_J_history[5000:], label='Test')
axs[1].set_xlabel('Iterations')
axs[1].set_ylabel('Cost')
axs[1].set_title('Cost vs. Iterations after 5000 iterations')
axs[1].legend()

plt.show()

# %%
# plot the model on the train and test data
fig, axs = plt.subplots(1, 2, figsize=(10,5))
fig.suptitle('Train and Test Data')
axs[0].plot(X_train[:, 0:1], X_train_scaled_ones @ w_vanilla_gd, 'r')
axs[0].plot(X_train[:, 0:1], y_train, '.')
axs[0].set_title('Train Data')
axs[1].plot(X_test[:, 0:1], X_test_scaled_ones @ w_vanilla_gd, 'g')
axs[1].plot(X_test[:, 0:1], y_test, '.')
axs[1].set_title('Test Data')
plt.show()

# %%
# output the final RMSE for the training and test set
vanilla_gd_rmse_train = math.sqrt(J_history[-1])
vanilla_gd_rmse_test = math.sqrt(test_J_history[-1])
print("Final training RMSE: ",vanilla_gd_rmse_train)
print("Final test RMSE: ", vanilla_gd_rmse_test)
# Out:
# Final training RMSE:  0.0275051489373022
# Final test RMSE:  0.223883328649572

# %% [markdown]
# ## Analysis: Overfitting Confirmed!
#
# **The Solution**: Add regularization to constrain parameter growth and improve generalization.
#
# **What You Should Observe:**
#
# - **Training RMSE**: Very low (model memorized training data)
#   - **The Problem**: Our model learned the noise, not the underlying pattern!
#
# - **Test RMSE**: Much higher (poor generalization)
#
# - **Learning curves**: Training cost ↓, Test cost ↑ (diverging lines)
# - **Visualizations**: Perfect fit on training, erratic on test data

# %% [markdown]
# ## Regularization: The Overfitting Solution
#
# **Core Concept**: Add a penalty term to the cost function that discourages large parameter values.
#
# **Why Regularization Works:**
# - **Constrains model complexity** by limiting parameter magnitude
# - **Improves generalization** by preventing memorization of training noise
# - **Provides smoothness** by preferring simpler, more stable solutions
# - **Reduces variance** while introducing controlled bias
#
# **Two Main Regularization Types:**
# - **L1 (Lasso)**: λ||w||₁ - Promotes sparsity, drives weights to exactly zero
# - **L2 (Ridge)**: λ||w||₂² - Shrinks weights smoothly, keeps all features active
#
# **Mathematical Intuition**: Both add penalty terms that grow with parameter magnitude, forcing the optimizer to balance fitting the data with keeping weights small.
#
# <b>Cost function for L1 regularized linear regression</b>
# \begin{equation}
# J(w) = 1/2m \sum_{i=1}^{m} (f_{\mathbf{w}}(\mathbf{x})^{(i)} - y^{(i)})^2 +\lambda/2m\sum_{j=1}^{n} |w_j|  \tag{1}
# \end{equation}
#
# **Vectorized L1 Regularized Cost Function with Summation**
#
# \begin{equation}
# J(W) = \frac{1}{2m} (XW - y)^T (XW - y) + \lambda \sum_{j=1}^{n} |w_j|   \tag{2}
# \end{equation}
#
# **L1 In Vectorized Form**
#
# \begin{equation}
# J(W) = \frac{1}{2m} (XW - y)^T (XW - y) + \lambda \| W \|_1   \tag{3}
# \end{equation}
#
# <b>Cost function for L2 regularized linear regression</b>
#
# \begin{equation}
# J(w) = 1/2m \sum_{i=1}^{m} (f_{\mathbf{w}}(\mathbf{x})^{(i)} - y^{(i)})^2 +\lambda/2m\sum_{j=1}^{n} w_j^2   \tag{4}
# \end{equation}
#
#
# **Vectorized L2 Regularized Cost Function with Summation**
#
# \begin{equation}
# J(W) = \frac{1}{2m} (XW - y)^T (XW - y) + \lambda \sum_{j=1}^{n} w_j^2    \tag{5}
# \end{equation}
#
# **L2 Regularized Cost Function in Vectorized Form**
#
# \begin{equation}
# J(W) = \frac{1}{2m} (XW - y)^T (XW - y) + \frac{\lambda}{2} \| W \|_2^2    \tag{6}
# \end{equation}
#
#
# Compare this to the cost function without regularization (which you implemented in  a previous lab), which is of the form:
#
#
# \begin{equation}
# J(W) = \frac{1}{2m} (XW - y)^T (XW - y)    \tag{7}
# \end{equation}
#
#
#
# The difference is the regularization term,  <span style="color:red">
#     $\frac{\lambda}{2m}  \sum_{j=1}^{n} w_j^2$ </span> and <span style="color:red">
#     $\frac{\lambda}{2m} \sum_{j=1}^{n} |w_j|$
#
# Including this term encourages gradient descent to minimize the size of the parameters.
#
#  **Note, in this example, the parameter $w_0$ is not regularized. This is standard practice.**

# %% [markdown]
# ## Gradient descent with regularization
# The basic algorithm for running gradient descent does not change with regularization, it is:
# $$\begin{align*}
# &\text{repeat until convergence:} \; \lbrace \\
# &  \; \; \;w_j = w_j -  \alpha \frac{\partial J(\mathbf{w})}{\partial w_j} \tag{1}  \; & \text{for j := 0..n} \\
# &\rbrace
# \end{align*}$$
# Where each iteration performs simultaneous updates on $w_j$ for all $j$.
#
# What changes with regularization is computing the gradients. Let's try L2 regularization next

# %% [markdown]
# ## Gradient For L2 regularization
#
# \begin{equation}
# \frac{\partial J(w)}{\partial w_j} = 1/m\sum_{i=1}^{m}(f_{\mathbf{w}}(\mathbf{x})^{(i)} - y^{(i)}).x_j^{(i)} + (\lambda/m)x_j^{(i)}  \tag{8}
# \end{equation}
#
#
# The term which adds regularization is  the <span style="color:red">
# $\frac{\lambda}{m} w_j ^{(i)}$</span>, the parameter $w_0$ is not regularized
#
# **Vectorized form**
#
# \begin{equation}
# W := W - \alpha \left( \frac{1}{m} X^T (XW - y) + \lambda W \right)    \tag{9}
# \end{equation}

# %% [markdown]
# ### Task 1: L2 Regularization Implementation (Ridge Regression)
#
# **Critical Note**: Do NOT regularize the bias term (w₀) - standard ML practice!
#
# **Objective**: Implement L2 regularization to combat overfitting through parameter shrinkage.
#
# - **Implementation**: Use vectorization for efficiency
#
# **Key Mathematical Changes:**- **Gradient**: Add λ * w regularization term to standard gradient
# - **Cost function**: Add λ/2 * ||w||₂² penalty term

# %%
def compute_cost_matrix_reg_l2(X, y, w, lambda_reg):
    """
    🎯 Computes L2 regularized cost for linear regression (Ridge Regression)
    
    Mathematical Formula: 
    J(w) = (1/2m) * ||Xw - y||² + (λ/2) * ||w[1:]||²
    
    Args:
      X (ndarray (m,n)): Feature matrix (including bias column)
      y (ndarray (m,)): Target values
      w (ndarray (n,)): Model parameters [bias, w1, w2, ..., wn]
      lambda_reg (float): Regularization strength (λ)
      
    Returns:
      cost (scalar): Total cost = MSE + L2 penalty
      
    Implementation Notes:

      - Don't regularize bias term: w[0] excluded from penalty

      - Use w[1:] for regularization term   

      - Vectorized: λ/2 * np.sum(w[1:]**2)    # cost = MSE_cost + (lambda_reg/2) * sum(w[1:]^2)

    """    # TODO: Implement L2 regularized cost

    m = X.shape[0]
    predicted_y = X @ w
    errors = predicted_y - y
    squared_errors = np.dot(errors.T, errors)
    cost = squared_errors / (2*m)

    reg_term = (lambda_reg / 2) * np.sum(w[1:]**2)
    reg_cost = cost + reg_term

    return reg_cost

# %%
# Function to calculate the gradient with L2 regularization
def compute_gradient_matrix_reg_l2(X, y, w, lambda_reg):
    """
    Computes the gradient for linear regression with L2 regularization
    
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      lambda_reg (float): regularization parameter
      
    Returns
      dj_dw (ndarray (n,1)): The gradient of the cost w.r.t. the parameters w.
    """
    # use vectorization to implement the gradient for linear regression with L2 regularization, do not regularize the bias term

    m = X.shape[0] 
    predicted_y = X @ w
    errors = predicted_y - y
    dj_dw = (X.T @ errors) / m
    reg_term = lambda_reg/m * w[1:]
    reg_term = np.concatenate(([0], reg_term))

    dj_dw_reg = dj_dw + reg_term
    
    return dj_dw_reg

# %%
# Function to perform gradient descent with L2 regularization
def gradient_descent_matrix_reg_l2(X, y, X_test, y_test, w_in, alpha, num_iters, lambda_reg):
    """
    Performs batch gradient descent to learn w. Updates w by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (?,n+1))   : Training Data, m examples with n features
      y (ndarray (?,))    : Training target values
      X_test (ndarray (?,n+1))   : Test set, m examples with n features
      y_test (ndarray (?,))    : target values in test set
      w_in (ndarray (n+1,)) : initial model parameters  
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent
      lambda_reg (float)  : regularization parameter
      
    Returns:
      w (ndarray (n+1,)) : Updated values of parameters
      J_history           : Cost of the model after each iteration
      test_J_history      : Cost of the model on test set after each iteration
      """
    
    # implement the batch gradient descent algorithm with L2 regularization using the compute_gradient and compute_cost functions
   

        # print cost every 5000 iterations

    J_history = []
    test_J_history = []
    w = copy.deepcopy(w_in)

    for i in range(num_iters):
        gradient = compute_gradient_matrix_reg_l2(X, y, w, lambda_reg)
        w = w - (alpha*gradient)
        cost = compute_cost_matrix_reg_l2(X, y, w, lambda_reg)
        J_history.append(cost)
        test_cost = compute_cost_matrix_reg_l2(X_test, y_test, w, lambda_reg)
        test_J_history.append(test_cost)
        if i % 5000 == 0:
            print(f"For iteration {i+1}/{num_iters}, the training cost is {cost}.")
            print(f"For iteration {i+1}/{num_iters}, the test cost is {test_cost}.")

    
    return w, J_history, test_J_history

# %%
# initialize the model parameters to 0
w = np.zeros(X_train_scaled_ones.shape[1])
# run the gradient descent algorithm for 1000 iterations with a learning rate of 0.01 and lambda = 0.1
alpha = 0.1
num_iters = 60000
lambda_l2 = 0.004
GD_L2_w, J_history, test_J_history = gradient_descent_matrix_reg_l2(X_train_scaled_ones, y_train, X_test_scaled_ones, y_test, w, alpha, num_iters, lambda_l2)
print(f"w found by gradient descent with regularization: {GD_L2_w} ")
# Out:
# For iteration 1/60000, the training cost is 0.18670490135675144.
# For iteration 1/60000, the test cost is 0.20929874189962575.
# For iteration 5001/60000, the training cost is 0.010692553975186671.
# For iteration 5001/60000, the test cost is 0.053765238255702945.
# For iteration 10001/60000, the training cost is 0.014031837798464548.
# For iteration 10001/60000, the test cost is 0.048132374575475444.
# For iteration 15001/60000, the training cost is 0.016575887659605902.
# For iteration 15001/60000, the test cost is 0.04865576630958582.
# For iteration 20001/60000, the training cost is 0.01804781778460466.
# For iteration 20001/60000, the test cost is 0.049667903863527124.
# For iteration 25001/60000, the training cost is 0.018827336375835245.
# For iteration 25001/60000, the test cost is 0.05032318032929317.
# For iteration 30001/60000, the training cost is 0.019225927560700865.
# For iteration 30001/60000, the test cost is 0.0506671359550451.
# For iteration 35001/60000, the training cost is 0.019427010566642203.
# For iteration 35001/60000, the test cost is 0.05083014062060999.
# For iteration 40001/60000, the training cost is 0.019528178174636007.
# For iteration 40001/60000, the test cost is 0.0509006257965625.
# For iteration 45001/60000, the training cost is 0.0195792822685528.
# For iteration 45001/60000, the test cost is 0.050926952514096714.
# For iteration 50001/60000, the training cost is 0.019605346412260204.
# For iteration 50001/60000, the test cost is 0.050933451555552.
# For iteration 55001/60000, the training cost is 0.019618845664840512.
# For iteration 55001/60000, the test cost is 0.05093179610474122.
# w found by gradient descent with regularization: [-0.09443169  0.68216965 -2.07547182 -1.01251535  0.18904816  0.7674349
#   0.87965241  0.75634026  0.54518555  0.3220876   0.12032046 -0.04897358
#  -0.18510026 -0.29170039 -0.37373983 -0.43613285]

# %%
# plot the cost over the iterations
plt.plot(J_history, label='Training')
plt.plot(test_J_history, label='Test')
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost vs Iterations')
plt.legend()
plt.show()

# %%
# putting the above figures side by side for comparision, using subplots
fig, axs = plt.subplots(1, 2, figsize=(10,5))
fig.suptitle('Train and Test Data')
axs[0].plot(X_train[:, 0:1], X_train_scaled_ones @ GD_L2_w, 'r')
axs[0].plot(X_train[:, 0:1], y_train, '.')
axs[0].set_title('Train Data')
axs[1].plot(X_test[:, 0:1], X_test_scaled_ones @ GD_L2_w, 'g')
axs[1].plot(X_test[:, 0:1], y_test, '.')
axs[1].set_title('Test Data')
plt.show()

# %% [markdown]
# ### Task2: output the final RMSE for the training and test set below for performance comparision at the end

# %%
# output the final RMSE for the training and test set

l2_gd_rmse_train = math.sqrt(J_history[-1])
l2_gd_rmse_test = math.sqrt(test_J_history[-1])
print("Final training RMSE: ",l2_gd_rmse_train)
print("Final test RMSE: ", l2_gd_rmse_test)
# Out:
# Final training RMSE:  0.1400927937939959
# Final test RMSE:  0.22567090531815887

# %% [markdown]
# ## Using L1 Regularization to fix the overfitting issue
#
# The L1 gradient formula can be found below.
#
# \begin{equation}
# W := W - \alpha \left( \frac{1}{m} X^T (XW - y) + \lambda \, \text{sgn}(W) \right)    \tag{10}
# \end{equation}
#
#
# ### L1 Implementation Challenges: Understanding the Difficulties
#
# Using gradient descent for L1 regularization (Lasso) presents unique optimization challenges:
#
# #### Primary Challenge: Non-differentiability
# * **Problem**: The L1 penalty |w| is not differentiable at w = 0
# * **Impact**: Gradient becomes undefined at zero points, causing optimization instability
# * **Result**: Standard gradient descent may struggle near sparse solutions
#
# #### Professional Solutions:
#
# * **Coordinate Descent**: Update one parameter at a time (sklearn's approach)Let's implement L1 regularization and observe both its benefits and challenges!
#
# * **Subgradient Methods**: Use sign function approximation (our approach)
#
# * **Proximal Methods**: Advanced techniques for non-smooth optimization**Key Insight**: This is why professional libraries like sklearn use specialized algorithms rather than vanilla gradient descent for Lasso regression.
#
# * **Soft Thresholding**: Analytical solutions for certain cases
#
# We'll implement the subgradient method using `np.sign()` to approximate the L1 gradient. While this may show some convergence challenges, it demonstrates the core concepts and mathematical foundations.
#
# #### Our Educational Approach

# %% [markdown]
# ### Task 3: L1 Regularization Implementation (Lasso Regression)
#
# **Expected Outcome**: Some polynomial features should be eliminated (coefficients → 0)!
#
# **Objective**: Implement L1 regularization for automatic feature selection and overfitting prevention.
#
# - **Sparsity**: Expect some coefficients to become exactly zero
#
# **Key Implementation Details:**
#
# - **Sign function**: Use np.sign() for gradient computation
#
# - **Cost function**: Add λ * ||w||₁ penalty term
# - **Gradient**: Add λ * sign(w) to standard gradient

# %%
# Function to calculate the cost with L1 regularization
def compute_cost_matrix_reg_l1(X, y, w, lambda_reg):
    """
    Computes the cost for linear regression with L1 regularization
    
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      lambda_reg (float): regularization parameter
      
    Returns
      cost: (scalar)
    """
    # use vectorization to implement the cost for linear regression with L1 regularization, do not regularize the bias term
    m = X.shape[0]
    predicted_y = X @ w
    errors = predicted_y - y
    squared_errors = np.dot(errors.T, errors)
    cost = squared_errors / (2*m)

    reg_term = lambda_reg * np.sum(np.abs(w[1:]))
    reg_cost = cost + reg_term

    return reg_cost

# %%
# Function to calculate the gradient with L1 regularization
def compute_gradient_matrix_reg_l1(X, y, w, lambda_reg):
    """
    Computes the gradient for linear regression with L1 regularization
    
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters
      lambda_reg (float): regularization parameter
      
    Returns
      dj_dw (ndarray (n,1)): The gradient of the cost w.r.t. the parameters w.
    """
    # use vectorization to implement the gradient for linear regression with L1 regularization, do not regularize the bias term

    m = X.shape[0] 
    predicted_y = X @ w
    errors = predicted_y - y
    dj_dw = (X.T @ errors) / m
    reg_term = lambda_reg/m * np.sign(w[1:])
    reg_term = np.concatenate(([0], reg_term))

    dj_dw_reg = dj_dw + reg_term
    
    return dj_dw_reg

# %%
# Function to perform gradient descent with L1 regularization
def gradient_descent_matrix_reg_l1(X, y, X_test, y_test, w_in, alpha, num_iters, lambda_reg):
    """
    Performs batch gradient descent to learn w. Updates w by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (?,n+1))   : Training Data, m examples with n features
      y (ndarray (?,))    : Training target values
      X_test (ndarray (?,n+1))   : Test set, m examples with n features
      y_test (ndarray (?,))    : target values in test set
      w_in (ndarray (n+1,)) : initial model parameters  
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent
      lambda_reg (float)  : regularization parameter
      
    Returns:
      w (ndarray (n+1,)) : Updated values of parameters
      J_history           : Cost of the model after each iteration
      test_J_history      : Cost of the model on test set after each iteration
      """
    
    # implement the batch gradient descent algorithm using the compute_gradient and compute_cost functions
   

        # print cost every 5000 iterations

    J_history = []
    test_J_history = []
    w = copy.deepcopy(w_in)

    for i in range(num_iters):
        gradient = compute_gradient_matrix_reg_l1(X, y, w, lambda_reg)
        w = w - (alpha*gradient)
        cost = compute_cost_matrix_reg_l1(X, y, w, lambda_reg)
        J_history.append(cost)
        test_cost = compute_cost_matrix_reg_l1(X_test, y_test, w, lambda_reg)
        test_J_history.append(test_cost)
        if i % 5000 == 0:
            print(f"For iteration {i+1}/{num_iters}, the cost is {cost}.")
            print(f"For iteration {i+1}/{num_iters}, the test cost is {test_cost}.")
    
    return w, J_history, test_J_history

# %%
# initialize the model parameters to 0
w = np.zeros(X_train_scaled_ones.shape[1])
# run the gradient descent algorithm for 1000 iterations with a learning rate of 0.01 and lambda = 0.1
alpha = 0.1
num_iters = 60000
lambda_l1 = 0.004
GD_L1_w, J_history, test_J_history = gradient_descent_matrix_reg_l1(X_train_scaled_ones, y_train, X_test_scaled_ones, y_test, w, alpha, num_iters, lambda_l1)
print(f"w found by gradient descent with L1 regularization: {GD_L1_w} ")
# Out:
# For iteration 1/60000, the cost is 0.18729684256329882.
# For iteration 1/60000, the test cost is 0.20989068310617312.
# For iteration 5001/60000, the cost is 0.018788581275855937.
# For iteration 5001/60000, the test cost is 0.06775034405348748.
# For iteration 10001/60000, the cost is 0.021794834269954093.
# For iteration 10001/60000, the test cost is 0.06186098289537401.
# For iteration 15001/60000, the cost is 0.024002778922496776.
# For iteration 15001/60000, the test cost is 0.05910116215483249.
# For iteration 20001/60000, the cost is 0.02524356719777926.
# For iteration 20001/60000, the test cost is 0.05759230395515802.
# For iteration 25001/60000, the cost is 0.026200237642245758.
# For iteration 25001/60000, the test cost is 0.05664721157884778.
# For iteration 30001/60000, the cost is 0.026765422731558894.
# For iteration 30001/60000, the test cost is 0.05587978164876384.
# For iteration 35001/60000, the cost is 0.027721420835319116.
# For iteration 35001/60000, the test cost is 0.055590158487600475.
# For iteration 40001/60000, the cost is 0.028392430410003937.
# For iteration 40001/60000, the test cost is 0.05553682992560467.
# For iteration 45001/60000, the cost is 0.02884146112795322.
# For iteration 45001/60000, the test cost is 0.055499168192727044.
# For iteration 50001/60000, the cost is 0.029132365386478697.
# For iteration 50001/60000, the test cost is 0.05544401218009246.
# For iteration 55001/60000, the cost is 0.02930942105553375.
# For iteration 55001/60000, the test cost is 0.05538529567320918.
# w found by gradient descent with L1 regularization: [-9.44316904e-02  9.51376705e-01 -3.06491567e+00 -9.43422424e-05
#   9.79839721e-06  1.21727300e+00  1.10500115e+00  6.20949099e-02
#   4.05922926e-05 -2.99046145e-05 -1.98746958e-05 -1.31847891e-04
#  -4.04540428e-05 -1.39868734e-04 -4.89098095e-02 -3.80933281e-01]

# %%
# plot the cost over the iterations
plt.plot(J_history, label='Training')
plt.plot(test_J_history, label='Test')

plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Cost vs Iterations')
plt.legend()
plt.show()

# %%
# putting the above figures side by side for comparision, using subplots
fig, axs = plt.subplots(1, 2, figsize=(10,5))
fig.suptitle('Train and Test Data')
axs[0].plot(X_train[:, 0:1], X_train_scaled_ones @ GD_L1_w, 'r')
axs[0].plot(X_train[:, 0:1], y_train, '.')
axs[0].set_title('Train Data')
axs[1].plot(X_test[:, 0:1], X_test_scaled_ones @ GD_L1_w, 'g')
axs[1].plot(X_test[:, 0:1], y_test, '.')
axs[1].set_title('Test Data')
plt.show()

# %% [markdown]
# ### Task4: output the final RMSE for the training and test set below for performance comparision at the end

# %%
# output the final RMSE for the training and test set

l1_gd_rmse_train = math.sqrt(J_history[-1])
l1_gd_rmse_test = math.sqrt(test_J_history[-1])
print("Final training RMSE: ",l1_gd_rmse_train)
print("Final test RMSE: ", l1_gd_rmse_test)
# Out:
# Final training RMSE:  0.1714793895653673
# Final test RMSE:  0.23515004544600426

# %% [markdown]
# ## Professional Implementation: Scikit-Learn's Optimized Algorithms
#
#
# **Why Compare with Sklearn?**
#
# - **Parameters**: Different hyperparameter conventions (alpha vs. lambda)
#
# - **Industry Standard**: Production-ready, optimized implementations
# - **Performance**: Optimized C/Fortran backends for speed
#
# - **Advanced Algorithms**: Coordinate descent for Lasso, efficient solvers for Ridge
# - **Stability**: Professional implementations handle edge cases better
#
# - **Performance Benchmark**: Compare your implementations with professional tools
# - **Convergence**: Sklearn may converge faster due to advanced optimization
#
# - **Real-World Relevance**: Understand when to build custom vs. use libraries

# %% [markdown]
# ### Task 5: Professional Ridge Regression with Scikit-Learn
#
# **Comparison Focus**: How do sklearn's parameters compare to your custom implementation?
#
# **Implementation Requirements:**
#
# - Use `Ridge(alpha=0.004, max_iter=10000)` for fair comparison- Extract learned parameters using `.coef_` and `.intercept_`
#
# - Fit on scaled training data: `X_train_scaled`, `y_train`- Predict on both training and test sets

# %%
# use Ridge regression from sklearn to learn the model parameters
# alpha=0.004, max_iter=10000 

ridge_model = Ridge(alpha=0.004, max_iter=10000)
ridge_model.fit(X_train_scaled, y_train)
ridge_w = ridge_model.coef_
ridge_intercept = ridge_model.intercept_
print(f"w found by Ridge regression from sklearn: {ridge_w} ")
print(f"Intercept found by Ridge regression from sklearn: {ridge_intercept} ")
# Out:
# w found by Ridge regression from sklearn: [ 0.68317146 -2.07864713 -1.01132877  0.1916362   0.76887686  0.87940349
#   0.75488447  0.54324044  0.32025102  0.11897939 -0.04962267 -0.18499861
#  -0.29087521 -0.37226435 -0.4340992 ]
# Intercept found by Ridge regression from sklearn: -0.09443169035226882

# %% [markdown]
# ### Task6: Output the RMSE for the Ridge regression

# %%
# output the final RMSE for the training and test set

train_predictions = ridge_model.predict(X_train_scaled)
test_predictions = ridge_model.predict(X_test_scaled)
ridge_rmse_train = math.sqrt(np.mean((train_predictions - y_train) ** 2))
ridge_rmse_test = math.sqrt(np.mean((test_predictions - y_test) ** 2))
print("Final training RMSE from Ridge regression: ", ridge_rmse_train)
print("Final test RMSE from Ridge regression: ", ridge_rmse_test)
# Out:
# Final training RMSE from Ridge regression:  0.06859784497256215
# Final test RMSE from Ridge regression:  0.25930279992193495

# %% [markdown]
# ### Task 7: Professional Lasso Regression with Scikit-Learn
#
# **Sparsity Investigation**: Which polynomial terms does Lasso eliminate as irrelevant?
#
# **Implementation Requirements:**
#
# - Use `Lasso(alpha=0.004, max_iter=10000)` for consistency
# - Compare sparsity pattern with your custom L1 implementation
#
# - Apply to standardized data for proper regularization
#
# **Key Analysis**: Count how many coefficients are exactly zero

# %%
# Use lasso regression from sklearn to learn the model parameters
# alpha=0.004, max_iter=10000

lasso_model = Lasso(alpha=0.004, max_iter=10000)
lasso_model.fit(X_train_scaled, y_train)
lasso_w = lasso_model.coef_
lasso_intercept = lasso_model.intercept_
print(f"w found by Lasso regression from sklearn: {lasso_w} ")
print(f"Intercept found by Lasso regression from sklearn: {lasso_intercept} ")
# Out:
# w found by Lasso regression from sklearn: [-0.         -1.27800488 -0.          0.          0.          0.
#   0.57624013  0.49526164  0.          0.          0.          0.
#   0.          0.          0.        ]
# Intercept found by Lasso regression from sklearn: -0.09443169035226888

# %% [markdown]
# ### Task 8: Lasso Performance Analysis
#
# **Evaluation Requirements:**
# - Calculate and output final RMSE for both training and test sets
# - **Sparsity Analysis**: Count and report how many coefficients are exactly zero
# - **Feature Selection**: Identify which polynomial terms were eliminated
# - **Compare**: How does Lasso sparsity compare to your custom L1 implementation?

# %%
# output the final RMSE for the training and test set

train_predictions = lasso_model.predict(X_train_scaled)
test_predictions = lasso_model.predict(X_test_scaled)
lasso_rmse_train = math.sqrt(np.mean((train_predictions - y_train) ** 2))
lasso_rmse_test = math.sqrt(np.mean((test_predictions - y_test) ** 2))
print("Final training RMSE from Lasso regression: ", lasso_rmse_train)
print("Final test RMSE from Lasso regression: ", lasso_rmse_test)
# Out:
# Final training RMSE from Lasso regression:  0.11747428469868576
# Final test RMSE from Lasso regression:  0.3432830980957859

# %% [markdown]
# ## Comprehensive Analysis: Comparing All Approaches
#
# **Comparative Study Objectives:**
# - **Parameter Analysis**: How do learned weights differ across methods?
# - **Performance Evaluation**: Which approach generalizes best?
# - **Implementation Insights**: Custom vs. professional implementations
# - **Method Selection**: When to use L1 vs. L2 vs. no regularization
#
# **Expected Discoveries:**
# - Regularized models should show better generalization (lower test RMSE)
# - L1 methods should produce sparse solutions with zero coefficients
# - L2 methods should shrink all parameters uniformly
# - Professional implementations may outperform custom gradient descent

# %% [markdown]
# ### Task 9: Parameter Comparison Matrix
#
# **Create a comprehensive DataFrame comparing all learned parameters:**
#
# **Models to Include:**
#
# - Vanilla GD (baseline overfitted model)
# - Custom L2 Regularization (Ridge)
# - Custom L1 Regularization (Lasso)
# - Sklearn Ridge Regression
# - Sklearn Lasso Regression
#
# **DataFrame Structure:**
#
# - **Rows**: Each polynomial feature (x¹, x², ..., x¹⁵) + bias term
# - **Columns**: Each model's learned parameters
# - **Analysis**: Identify patterns, sparsity, parameter magnitude differences
#
# **Key Questions to Investigate:**
#
# 1. Which coefficients does L1 drive to zero?
# 2. How do L2 parameters compare in magnitude to unregularized?
# 3. Are sklearn and custom implementations learning similar patterns?
#
# - **Rows**: Each polynomial feature (x¹, x², ..., x¹⁵) + bias term
#
# **Models to Include:**
#
# - Vanilla GD (baseline overfitted model)
#
# - Custom L2 Regularization (Ridge)- Sklearn Lasso Regression
#
# - Custom L1 Regularization (Lasso) - Sklearn Ridge Regression

# %%
#putting all the parameters from the above models in a dataframe, adding the bias term to the model parameters

models = pd.DataFrame({
    'Vanilla_GD': w_vanilla_gd, 
    'Custom L2 Regularization': GD_L2_w,
    'Custom L1 Regularization': GD_L1_w,
    'Ridge_Regression': np.concatenate(([ridge_intercept], ridge_w)),
    'Lasso_Regression': np.concatenate(([lasso_intercept], lasso_w))
})

models
# Out:
#     Vanilla_GD  Custom L2 Regularization  Custom L1 Regularization  \
# 0    -0.094432                 -0.094432                 -0.094432
# 1     1.451011                  0.682170                  0.951377
# 2    -3.311383                 -2.075472                 -3.064916
# 3    -1.465804                 -1.012515                 -0.000094
# 4     0.499038                  0.189048                  0.000010
# 5     1.352924                  0.767435                  1.217273
# 6     1.432393                  0.879652                  1.105001
# 7     1.154671                  0.756340                  0.062095
# 8     0.769085                  0.545186                  0.000041
# 9     0.393416                  0.322088                 -0.000030
# 10    0.072289                  0.120320                 -0.000020
# 11   -0.184788                 -0.048974                 -0.000132
# 12   -0.383031                 -0.185100                 -0.000040
# 13   -0.532458                 -0.291700                 -0.000140
# 14   -0.643492                 -0.373740                 -0.048910
# 15   -0.725256                 -0.436133                 -0.380933
#
#     Ridge_Regression  Lasso_Regression
# 0          -0.094432         -0.094432
# 1           0.683171         -0.000000
# 2          -2.078647         -1.278005
# 3          -1.011329         -0.000000
# 4           0.191636          0.000000
# 5           0.768877          0.000000
# 6           0.879403          0.000000
# 7           0.754884          0.576240
# 8           0.543240          0.495262
# 9           0.320251          0.000000
# 10          0.118979          0.000000
# 11         -0.049623          0.000000
# 12         -0.184999          0.000000
# 13         -0.290875          0.000000
# 14         -0.372264          0.000000
# 15         -0.434099          0.000000

# %% [markdown]
# 1. L1 drives coefficients 1, 3, 4, 5, 6, 9, 10, 11, 12, 13, 14, and 15 to zero.
# 2. Almost every coefficient, unless it was already quite small, is smaller in the L2 regularization compared to the vanilla GD.
# 3. Yes, they are very similar, but custom L2 and ridge are much closer it seems than custom L1 and lasso.

# %% [markdown]
# ### Task 10: Performance Leaderboard Analysis
#
# **Expected Insights**: Regularized models should show better generalization!
#
# **Create a comprehensive performance comparison:**
#
# * How do custom implementations compare to sklearn?
# * When would you choose L1 vs L2 regularization?
#
# **Metrics to Compare:**
#
# **Metrics to Compare:**
#
# - Training RMSE (overfitting indicator)
# - Test RMSE (generalization measure)
# - Generalization Gap (Test RMSE - Train RMSE)
# - Number of Zero Coefficients (sparsity measure)
#
# **Analysis Questions:**
#
# 1. Which method has the best test performance?
# 2. Which method shows least overfitting (smallest gap)?
# 3. How do custom implementations compare to sklearn?
# 4. When would you choose L1 vs L2 regularization?
#
# **Expected Insights**: Regularized models should show better generalization!

# %%
# putting all the RMSE values in a dataframe
models = pd.DataFrame({
    'RMSE': ['Train', 'Test', 'Generalization Gap'],
    'Vanilla_GD': np.array([vanilla_gd_rmse_train, vanilla_gd_rmse_test, vanilla_gd_rmse_test - vanilla_gd_rmse_train]), 
    'Custom L2 Regularization': np.array([l2_gd_rmse_train, l2_gd_rmse_test, l2_gd_rmse_test - l2_gd_rmse_train]),
    'Custom L1 Regularization': np.array([l1_gd_rmse_train, l1_gd_rmse_test, l2_gd_rmse_test - l1_gd_rmse_train]),
    'Ridge_Regression': np.array([ridge_rmse_train, ridge_rmse_test, ridge_rmse_test - ridge_rmse_train]),
    'Lasso_Regression': np.array([lasso_rmse_train, lasso_rmse_test, lasso_rmse_test - lasso_rmse_train])
})

models
# Out:
#                  RMSE  Vanilla_GD  Custom L2 Regularization  \
# 0               Train    0.027505                  0.140093
# 1                Test    0.223883                  0.225671
# 2  Generalization Gap    0.196378                  0.085578
#
#    Custom L1 Regularization  Ridge_Regression  Lasso_Regression
# 0                  0.171479          0.068598          0.117474
# 1                  0.235150          0.259303          0.343283
# 2                  0.054192          0.190705          0.225809

# %% [markdown]
# 1. Vanilla GD has the best test performance overall, but out of the regularized models, my custom L2 regularization has the best test performance.
# 2. My custom L1 regularization model shows the least overfitting (smallest gap).
# 3. My custom ones in general perform better than the sklearn couterparts both for test performance and generalization gap.
# 4. You should choose L1 regularization when you want natural feature selection to occur, but if you want all feature to remain in the model and not have their coefficients shrink to small values, you should choose L2 regularization.

# %% [markdown]
# ## Congratulations! You've Mastered Regularized Machine Learning!
#
#
# ### Key Achievements Unlocked:
#
# #### Technical Mastery
#
# * **Regularized Cost Functions**: Successfully extended MSE with L1/L2 penalty terms
# * **Advanced Gradient Descent**: Implemented vectorized algorithms with regularization
# * **Professional Tools**: Leveraged scikit-learn's optimized Lasso and Ridge implementations
# * **Comparative Analysis**: Systematically evaluated custom vs. professional approaches
#
# #### Conceptual Understanding
#
# * **Overfitting Recognition**: Identified and diagnosed overfitting through learning curves
# * **Bias-Variance Tradeoff**: Observed how regularization balances model complexity
# * **L1 vs L2 Intuition**: Understood sparsity (L1) vs. shrinkage (L2) effects
# * **Hyperparameter Impact**: Explored how λ controls regularization strength
#
# #### Professional Insights
#
# * **When to Regularize**: Small datasets + high dimensions = regularization essential
# * **Method Selection**: L1 for feature selection, L2 for smooth parameter shrinkage
# * **Implementation Choices**: Custom for learning, sklearn for production
# * **Performance Evaluation**: Always compare training vs. test performance
#
# ### Real-World Applications
#
# You're now equipped to tackle overfitting in:
#
# - **Medical Diagnosis**: High-dimensional genomic data
# - **Financial Modeling**: Feature-rich economic indicators
# - **Image Recognition**: Pixel-level feature engineering
# - **Natural Language Processing**: Large vocabulary models
#
# **Next Steps**: Apply these techniques to your own datasets and explore advanced regularization methods like Elastic Net!

# %% [markdown]
# ## Reference
#
# Deeplearning.AI
